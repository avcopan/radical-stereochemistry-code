# %%
import pandas
import automol
import ioformat
import helpers

# %%
# 1. read in the non-redundantly expanded species and reaction lists
NREX_C67_SPC_PATH = 'species/02_species-nr-exp_nuig-c6-7.csv'
NREX_C67_RXN_PATH = 'reactions/04_reactions-nr-exp_nuig-c6-7.csv'
NREX_PYR_SPC_PATH = 'species/02_species-nr-exp_nuig-pyro.csv'
NREX_PYR_RXN_PATH = 'reactions/04_reactions-nr-exp_nuig-pyro.csv'

NREX_C67_SPC_DF = pandas.read_csv(NREX_C67_SPC_PATH, quotechar="'")
NREX_C67_RXN_DF = pandas.read_csv(NREX_C67_RXN_PATH, quotechar="'")
NREX_PYR_SPC_DF = pandas.read_csv(NREX_PYR_SPC_PATH, quotechar="'")
NREX_PYR_RXN_DF = pandas.read_csv(NREX_PYR_RXN_PATH, quotechar="'")

# %%
# 2. add missing non-canonical species enantiomers back into
#    non-redundant species list, adding columns containing
#    racemic ChIs and racemic CHEMKIN names
def add_missing_species_enantiomers(spc_df):
    row_dcts = []
    count = len(spc_df.index)
    for num, row0 in spc_df.iterrows():
        print(f'Row {num}/{count}')
        row_dct0 = row0.to_dict()
        name0 = row_dct0['name']
        chi0 = row_dct0['inchi']
        smi0 = row_dct0['smiles']
        # racemic name/ChI
        is_enant = automol.chi.is_enantiomer(chi0)
        namer = helpers.racemic_species_name(name0, chi0)
        chir = automol.chi.racemic(chi0)
        print(f'Species: {name0}')
        print(f' - ChI: {chi0}')
        print(f' - SMILES: {smi0}')
        row_dct0.update({
            'name': name0,
            'racem-name': namer,
            'racem-inchi': chir,
            'is_enant': is_enant,
        })
        row_dcts.append(row_dct0)
        if is_enant:
            print(f' - Species is chiral.')
            print(f' - Racemic name: {namer}')
            print(f' - Racemic ChI: {chir}')
            print(f' - Checking for missing enantiomer...')
            # name/ChI for other enantiomer
            name1 = helpers.reflect_species_name(name0, chi0)
            if name1 not in spc_df.index:
                chi1 = automol.chi.reflect(chi0)
                smi1 = automol.smiles.reflect(smi0)
                print(f' - Missing enantiomer: {name1}')
                print(f'   - ChI: {chi1}')
                print(f'   - SMILES: {smi1}')
                row_dct1 = row_dct0.copy()
                row_dct1.update({
                    'name': name1,
                    'inchi': chi1,
                    'smiles': smi1,
                    'is_enant': is_enant,
                })
                row_dcts.append(row_dct1)
    ex_spc_df = pandas.DataFrame.from_records(row_dcts)
    return ex_spc_df

# %%
print('Retrieving full NUIG-C6-7 species expansion from non-redundant list')
FUEX_C67_SPC_DF = add_missing_species_enantiomers(NREX_C67_SPC_DF)

# %%
print('Retrieving full NUIG-Pyro species expansion from non-redundant list')
FUEX_PYR_SPC_DF = add_missing_species_enantiomers(NREX_PYR_SPC_DF)

# %%
# 2. add missing non-canonical reaction enantiomers back into
#    non-redundant reaction list, adding columns with racemic
#    CHEMKIN names
def add_missing_reaction_enantiomers(rxn_df, spc_df):
    """ Add missing enantiomers back into non-redundant raction list
    
        :param rxn_df: fully or non-redundantly expanded reaction list
        :param spc_df: fully expanded species list, with 'racem-name'
            and 'racem-inchi' columns added
    """
    row_dcts = []
    count = len(rxn_df.index)
    chi_dct = dict(zip(spc_df['name'], spc_df['inchi']))
    for num, row0 in rxn_df.iterrows():
        print(f'Row {num}/{count}')
        row_dct0 = row0.to_dict()
        name0 = row_dct0['name']
        print(f'Reaction: {name0}')
        namer = helpers.racemic_reaction_name(name0, chi_dct)
        name1 = helpers.reflect_reaction_name(name0, chi_dct)
        num_rct_enants = helpers.chiral_reactant_count(name0, chi_dct)
        row_dct0.update({
            'name': name0,
            'racem-name': namer,
            'num-reac-enants': num_rct_enants,
        })
        row_dcts.append(row_dct0)
        if name1 is not None:
            print(f' - Reaction is chiral.')
            print(f' - Racemic name: {namer}')
            if name1 not in rxn_df.index:
                print(f' - Missing enantiomer: {name1}')
                row_dct1 = row_dct0.copy()
                ts_amchi = row_dct0['ts_amchi_stereo']
                row_dct1.update({
                    'name': name1,
                    'num-reac-enants': num_rct_enants,
                    'ts_amchi_stereo': automol.chi.reflect(ts_amchi),
                })
                row_dcts.append(row_dct1)
    ex_rxn_df = pandas.DataFrame.from_records(row_dcts).set_index('name')
    ex_rxn_df.insert(0, 'racem-name', ex_rxn_df.pop('racem-name'))
    return ex_rxn_df

# %%
print('Retrieving full NUIG-C6-7 reaction expansion from non-redundant list')
FUEX_C67_RXN_DF = add_missing_reaction_enantiomers(
    NREX_C67_RXN_DF, FUEX_C67_SPC_DF)
# Out:
# Row 2/5990
# Reaction: I3C6Q25-1-ABB1 = I3C6D1-5OOH-AB1 + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6Q25-1-ABBr = I3C6D1-5OOH-ABr + HO2
#  - Missing enantiomer: I3C6Q25-1-ABB0 = I3C6D1-5OOH-AB0 + HO2
# Row 3/5990
# Reaction: I3C6Q25-1-ABA1 = I3C6D1-5OOH-AA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6Q25-1-ABAr = I3C6D1-5OOH-AAr + HO2
#  - Missing enantiomer: I3C6Q25-1-ABA0 = I3C6D1-5OOH-AA0 + HO2
# Row 4/5990
# Reaction: I3C6-3 + H = I3C6
# Row 5/5990
# Reaction: I3C6Q16-4 = C4H71-4OOH + C2H4O2H
# Row 6/5990
# Reaction: NC5H12 + CH3O2 = C5H11-1 + CH3O2H
# Row 7/5990
# Reaction: IC6D4-3O-A0 = C2H3CHO + IC3H7
#  - Reaction is chiral.
#  - Racemic name: IC6D4-3O-Ar = C2H3CHO + IC3H7
#  - Missing enantiomer: IC6D4-3O-A1 = C2H3CHO + IC3H7
# Row 8/5990
# Reaction: C6H12OOH1-3O2-A0 = C6H11Q13-5-A0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH1-3O2-Ar = C6H11Q13-5-Ar
#  - Missing enantiomer: C6H12OOH1-3O2-A1 = C6H11Q13-5-A1
# Row 9/5990
# Reaction: C6H12OOH1-3O2-A1 = C6H11Q13-5-A1
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH1-3O2-Ar = C6H11Q13-5-Ar
#  - Missing enantiomer: C6H12OOH1-3O2-A0 = C6H11Q13-5-A0
# Row 10/5990
# Reaction: IC6OOH2-3 + O2 = IC6OOH2-3O2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH2-3 + O2 = IC6OOH2-3O2-Ar
#  - Missing enantiomer: IC6OOH2-3 + O2 = IC6OOH2-3O2-A1
# Row 11/5990
# Reaction: C6H111-3-Z = C6H112-5-Z
# Row 12/5990
# Reaction: C7H13Q26-3-AA0 = C7H13O23-6OOH-AAA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q26-3-AAr = C7H13O23-6OOH-AAAr + OH
#  - Missing enantiomer: C7H13Q26-3-AA1 = C7H13O23-6OOH-AAA1 + OH
# Row 13/5990
# Reaction: C7H13Q26-3-AB0 = C7H13O23-6OOH-ABB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q26-3-ABr = C7H13O23-6OOH-ABBr + OH
#  - Missing enantiomer: C7H13Q26-3-AB1 = C7H13O23-6OOH-ABB0 + OH
# Row 14/5990
# Reaction: C7H13Q26-3-AB1 = C7H13O23-6OOH-ABA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q26-3-ABr = C7H13O23-6OOH-ABAr + OH
#  - Missing enantiomer: C7H13Q26-3-AB0 = C7H13O23-6OOH-ABA1 + OH
# Row 15/5990
# Reaction: C7H13Q26-3-AA1 = C7H13O23-6OOH-AAB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q26-3-AAr = C7H13O23-6OOH-AABr + OH
#  - Missing enantiomer: C7H13Q26-3-AA0 = C7H13O23-6OOH-AAB0 + OH
# Row 16/5990
# Reaction: C7H15OOH-1 = C7H15-1O + OH
# Row 17/5990
# Reaction: IC6D1 + H = IC6D1-1A + H2
# Row 18/5990
# Reaction: IC6D1 + HO2 = IC6D1-5 + H2O2
# Row 19/5990
# Reaction: IC6 + O = IC6-1-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6 + O = IC6-1-Ar + OH
#  - Missing enantiomer: IC6 + O = IC6-1-A1 + OH
# Row 20/5990
# Reaction: IC6OOH3-4O2-AB0 = IC6D4-3OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-4O2-ABr = IC6D4-3OOH-Ar + HO2
#  - Missing enantiomer: IC6OOH3-4O2-AB1 = IC6D4-3OOH-A1 + HO2
# Row 21/5990
# Reaction: IC6OOH3-4O2-AA0 = IC6D4-3OOH-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-4O2-AAr = IC6D4-3OOH-Ar + HO2
#  - Missing enantiomer: IC6OOH3-4O2-AA1 = IC6D4-3OOH-A0 + HO2
# Row 22/5990
# Reaction: C6H13-2 + O2 = C6H12-2-Z + HO2
# Row 23/5990
# Reaction: C6H13-2 + O2 = C6H12-2-E + HO2
# Row 24/5990
# Reaction: IC5H12 + O2CHO = CC5H11 + HO2CHO
# Row 25/5990
# Reaction: C6H11Q15-4-A0 = C6H11O23-6OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q15-4-Ar = C6H11O23-6OOH-AAr + OH
#  - Missing enantiomer: C6H11Q15-4-A1 = C6H11O23-6OOH-AA1 + OH
# Row 26/5990
# Reaction: C6H11Q15-4-A1 = C6H11O23-6OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q15-4-Ar = C6H11O23-6OOH-ABr + OH
#  - Missing enantiomer: C6H11Q15-4-A0 = C6H11O23-6OOH-AB0 + OH
# Row 27/5990
# Reaction: SC4H9CHO-A1 + CH3 = SC4H9CO-A1 + CH4
#  - Reaction is chiral.
#  - Racemic name: SC4H9CHO-Ar + CH3 = SC4H9CO-Ar + CH4
#  - Missing enantiomer: SC4H9CHO-A0 + CH3 = SC4H9CO-A0 + CH4
# Row 28/5990
# Reaction: XC6D1 + CH3O2 = XC6D1-3 + CH3O2H
# Row 29/5990
# Reaction: NC5D124 + CH3 = IC6D13-5R-ZE
# Row 30/5990
# Reaction: NC5D124 + CH3 = IC6D13-5R-ZZ
# Row 31/5990
# Reaction: NC5D124 + CH3 = IC6D13-5R-EE
# Row 32/5990
# Reaction: NC5D124 + CH3 = IC6D13-5R-EZ
# Row 33/5990
# Reaction: C7H14OOH1-4O-A0 = NC4KET14 + NC3H7
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH1-4O-Ar = NC4KET14 + NC3H7
#  - Missing enantiomer: C7H14OOH1-4O-A1 = NC4KET14 + NC3H7
# Row 34/5990
# Reaction: IC6OOH3-1O2-AA0 = IC6Q13-4-AA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-1O2-AAr = IC6Q13-4-AAr
#  - Missing enantiomer: IC6OOH3-1O2-AA1 = IC6Q13-4-AA1
# Row 35/5990
# Reaction: IC6OOH3-1O2-AB0 = IC6Q13-4-AB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-1O2-ABr = IC6Q13-4-ABr
#  - Missing enantiomer: IC6OOH3-1O2-AB1 = IC6Q13-4-AB1
# Row 36/5990
# Reaction: IC6OOH3-1O2-AB1 = IC6Q13-4-AB1
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-1O2-ABr = IC6Q13-4-ABr
#  - Missing enantiomer: IC6OOH3-1O2-AB0 = IC6Q13-4-AB0
# Row 37/5990
# Reaction: IC6OOH3-1O2-AA1 = IC6Q13-4-AA1
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-1O2-AAr = IC6Q13-4-AAr
#  - Missing enantiomer: IC6OOH3-1O2-AA0 = IC6Q13-4-AA0
# Row 38/5990
# Reaction: I3C6Q14-2-A1 = I3C6O24-1OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q14-2-Ar = I3C6O24-1OOH-AAr + OH
#  - Missing enantiomer: I3C6Q14-2-A0 = I3C6O24-1OOH-AA1 + OH
# Row 39/5990
# Reaction: I3C6Q14-2-A0 = I3C6O24-1OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q14-2-Ar = I3C6O24-1OOH-ABr + OH
#  - Missing enantiomer: I3C6Q14-2-A1 = I3C6O24-1OOH-AB0 + OH
# Row 40/5990
# Reaction: C2H3CHO + NC3H7 = NC5H10CHO-1-Z
# Row 41/5990
# Reaction: C2H3CHO + NC3H7 = NC5H10CHO-1-E
# Row 42/5990
# Reaction: IC6OOH1-5O2-A0 = IC6D4-1OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-5O2-Ar = IC6D4-1OOH-Ar + HO2
#  - Missing enantiomer: IC6OOH1-5O2-A1 = IC6D4-1OOH-A1 + HO2
# Row 43/5990
# Reaction: IC6OOH1-5O2-A1 = IC6D4-1OOH-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-5O2-Ar = IC6D4-1OOH-Ar + HO2
#  - Missing enantiomer: IC6OOH1-5O2-A0 = IC6D4-1OOH-A0 + HO2
# Row 44/5990
# Reaction: C6H13-1 + O2 = C6H12-1 + HO2
# Row 45/5990
# Reaction: C7H131-3O2-A0 = C7H121OOH3-5-A0
#  - Reaction is chiral.
#  - Racemic name: C7H131-3O2-Ar = C7H121OOH3-5-Ar
#  - Missing enantiomer: C7H131-3O2-A1 = C7H121OOH3-5-A1
# Row 46/5990
# Reaction: C7H131-3O2-A1 = C7H121OOH3-5-A1
#  - Reaction is chiral.
#  - Racemic name: C7H131-3O2-Ar = C7H121OOH3-5-Ar
#  - Missing enantiomer: C7H131-3O2-A0 = C7H121OOH3-5-A0
# Row 47/5990
# Reaction: C7H121-4-Z + H = CVCCJCVCCC-ZZZ + H2
# Row 48/5990
# Reaction: C7H121-4-E + H = CVCCJCVCCC-ZZE + H2
# Row 49/5990
# Reaction: C7H121-4-Z + H = CVCCJCVCCC-ZEZ + H2
# Row 50/5990
# Reaction: C7H121-4-E + H = CVCCJCVCCC-ZEE + H2
# Row 51/5990
# Reaction: C7H121-4-Z + H = CVCCJCVCCC-EZZ + H2
# Row 52/5990
# Reaction: C7H121-4-E + H = CVCCJCVCCC-EZE + H2
# Row 53/5990
# Reaction: C7H121-4-Z + H = CVCCJCVCCC-EEZ + H2
# Row 54/5990
# Reaction: C7H121-4-E + H = CVCCJCVCCC-EEE + H2
# Row 55/5990
# Reaction: IC6D4 + O = IC6D4-2 + OH
# Row 56/5990
# Reaction: XC6Q11A-4-A0 = C3H52-1,3OOH + C3H6
#  - Reaction is chiral.
#  - Racemic name: XC6Q11A-4-Ar = C3H52-1,3OOH + C3H6
#  - Missing enantiomer: XC6Q11A-4-A1 = C3H52-1,3OOH + C3H6
# Row 57/5990
# Reaction: I3C6 + O2 = I3C6-2-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6 + O2 = I3C6-2-Ar + HO2
#  - Missing enantiomer: I3C6 + O2 = I3C6-2-A1 + HO2
# Row 58/5990
# Reaction: I3C6 + O2 = I3C6-2-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6 + O2 = I3C6-2-Ar + HO2
#  - Missing enantiomer: I3C6 + O2 = I3C6-2-A0 + HO2
# Row 59/5990
# Reaction: C7H14-3-Z + H = C7H133-1-Z + H2
# Row 60/5990
# Reaction: C7H14-3-E + H = C7H133-1-E + H2
# Row 61/5990
# Reaction: I3C6KET2-6-A0 = I3C6KET2-6O-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6KET2-6-Ar = I3C6KET2-6O-Ar + OH
#  - Missing enantiomer: I3C6KET2-6-A1 = I3C6KET2-6O-A1 + OH
# Row 62/5990
# Reaction: C6H12OOH1-3 + O2 = C6H12OOH1-3O2-A0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH1-3 + O2 = C6H12OOH1-3O2-Ar
#  - Missing enantiomer: C6H12OOH1-3 + O2 = C6H12OOH1-3O2-A1
# Row 63/5990
# Reaction: C7H14OOH3-2O2-AA0 = C7H13Q23-5-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-2O2-AAr = C7H13Q23-5-AAr
#  - Missing enantiomer: C7H14OOH3-2O2-AA1 = C7H13Q23-5-AA1
# Row 64/5990
# Reaction: C7H14OOH3-2O2-AB0 = C7H13Q23-5-AB0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-2O2-ABr = C7H13Q23-5-ABr
#  - Missing enantiomer: C7H14OOH3-2O2-AB1 = C7H13Q23-5-AB1
# Row 65/5990
# Reaction: C7H14OOH3-2O2-AB1 = C7H13Q23-5-AB1
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-2O2-ABr = C7H13Q23-5-ABr
#  - Missing enantiomer: C7H14OOH3-2O2-AB0 = C7H13Q23-5-AB0
# Row 66/5990
# Reaction: C7H14OOH3-2O2-AA1 = C7H13Q23-5-AA1
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-2O2-AAr = C7H13Q23-5-AAr
#  - Missing enantiomer: C7H14OOH3-2O2-AA0 = C7H13Q23-5-AA0
# Row 67/5990
# Reaction: IC6-5 = IC6D4 + H
# Row 68/5990
# Reaction: IC6D1 + HO2 = IC6D1-1A + H2O2
# Row 69/5990
# Reaction: IC6OOH1-2O2-A0 = IC6D2-1OOH-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-2O2-Ar = IC6D2-1OOH-Z + HO2
#  - Missing enantiomer: IC6OOH1-2O2-A1 = IC6D2-1OOH-Z + HO2
# Row 70/5990
# Reaction: IC6OOH1-2O2-A1 = IC6D2-1OOH-E + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-2O2-Ar = IC6D2-1OOH-E + HO2
#  - Missing enantiomer: IC6OOH1-2O2-A0 = IC6D2-1OOH-E + HO2
# Row 71/5990
# Reaction: C3H4-A + C3H5-A = IC6D14-1
# Row 72/5990
# Reaction: I3C6D13 + HO2 = I3C6D13-5-Z + H2O2
# Row 73/5990
# Reaction: I3C6D13 + HO2 = I3C6D13-5-E + H2O2
# Row 74/5990
# Reaction: C6H103OOH2-1-ZA0 + O2 = C6H103OOH2-1O2-ZA1
#  - Reaction is chiral.
#  - Racemic name: C6H103OOH2-1-ZAr + O2 = C6H103OOH2-1O2-ZAr
#  - Missing enantiomer: C6H103OOH2-1-ZA1 + O2 = C6H103OOH2-1O2-ZA0
# Row 75/5990
# Reaction: C6H103OOH2-1-EA0 + O2 = C6H103OOH2-1O2-EA1
#  - Reaction is chiral.
#  - Racemic name: C6H103OOH2-1-EAr + O2 = C6H103OOH2-1O2-EAr
#  - Missing enantiomer: C6H103OOH2-1-EA1 + O2 = C6H103OOH2-1O2-EA0
# Row 76/5990
# Reaction: IC6Q12-3-A0 = IC6D2-1OOH-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6Q12-3-Ar = IC6D2-1OOH-Z + HO2
#  - Missing enantiomer: IC6Q12-3-A1 = IC6D2-1OOH-Z + HO2
# Row 77/5990
# Reaction: IC6Q12-3-A0 = IC6D2-1OOH-E + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6Q12-3-Ar = IC6D2-1OOH-E + HO2
#  - Missing enantiomer: IC6Q12-3-A1 = IC6D2-1OOH-E + HO2
# Row 78/5990
# Reaction: C6H101-3,4OOH-AA0 = C6H101O-3-4OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101-3,4OOH-AAr = C6H101O-3-4OOH-AAr + OH
#  - Missing enantiomer: C6H101-3,4OOH-AA1 = C6H101O-3-4OOH-AA1 + OH
# Row 79/5990
# Reaction: C6H101-3,4OOH-AB0 = C6H101O-3-4OOH-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101-3,4OOH-ABr = C6H101O-3-4OOH-ABr + OH
#  - Missing enantiomer: C6H101-3,4OOH-AB1 = C6H101O-3-4OOH-AB1 + OH
# Row 80/5990
# Reaction: C6H101OOH3-5-A0 = MVOX-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH3-5-Ar = MVOX-AAr + OH
#  - Missing enantiomer: C6H101OOH3-5-A1 = MVOX-AA1 + OH
# Row 81/5990
# Reaction: C6H101OOH3-5-A1 = MVOX-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH3-5-Ar = MVOX-ABr + OH
#  - Missing enantiomer: C6H101OOH3-5-A0 = MVOX-AB1 + OH
# Row 82/5990
# Reaction: IC6Q34-2-AA0 = IC6O23-4OOH-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q34-2-AAr = IC6O23-4OOH-ABr + OH
#  - Missing enantiomer: IC6Q34-2-AA1 = IC6O23-4OOH-AB1 + OH
# Row 83/5990
# Reaction: IC6Q34-2-AB0 = IC6O23-4OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q34-2-ABr = IC6O23-4OOH-AAr + OH
#  - Missing enantiomer: IC6Q34-2-AB1 = IC6O23-4OOH-AA1 + OH
# Row 84/5990
# Reaction: C6H111-3-Z + H = C6H12-1
# Row 85/5990
# Reaction: C6H111-3-E + H = C6H12-1
# Row 86/5990
# Reaction: IC6D13-Z + H = IC6D13-1AR-Z + H2
# Row 87/5990
# Reaction: IC6D13-E + H = IC6D13-1AR-E + H2
# Row 88/5990
# Reaction: NC5H11CHO + HO2 = NC5H10CHO-3 + H2O2
# Row 89/5990
# Reaction: NC6D1KET56 = NC6D1KET56O + OH
# Row 90/5990
# Reaction: C6H9-A-Z = CYHEXEN-4J
# Row 91/5990
# Reaction: IC6 + OH = IC6-3 + H2O
# Row 92/5990
# Reaction: XC6-2 = BC5H10 + CH3
# Row 93/5990
# Reaction: XC6D1 + O2CHO = XC6D1-3 + HO2CHO
# Row 94/5990
# Reaction: C6H11Q34-2-AB0 = C6H11-2D4OOH-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q34-2-ABr = C6H11-2D4OOH-ZAr + HO2
#  - Missing enantiomer: C6H11Q34-2-AB1 = C6H11-2D4OOH-ZA0 + HO2
# Row 95/5990
# Reaction: C6H11Q34-2-AB0 = C6H11-2D4OOH-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q34-2-ABr = C6H11-2D4OOH-EAr + HO2
#  - Missing enantiomer: C6H11Q34-2-AB1 = C6H11-2D4OOH-EA0 + HO2
# Row 96/5990
# Reaction: C6H11Q34-2-AA0 = C6H11-2D4OOH-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q34-2-AAr = C6H11-2D4OOH-ZAr + HO2
#  - Missing enantiomer: C6H11Q34-2-AA1 = C6H11-2D4OOH-ZA1 + HO2
# Row 97/5990
# Reaction: C6H11Q34-2-AA0 = C6H11-2D4OOH-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q34-2-AAr = C6H11-2D4OOH-EAr + HO2
#  - Missing enantiomer: C6H11Q34-2-AA1 = C6H11-2D4OOH-EA1 + HO2
# Row 98/5990
# Reaction: C6H11-1D5O-A1 = CH3CHO + C4H71-4
#  - Reaction is chiral.
#  - Racemic name: C6H11-1D5O-Ar = CH3CHO + C4H71-4
#  - Missing enantiomer: C6H11-1D5O-A0 = CH3CHO + C4H71-4
# Row 99/5990
# Reaction: C6H12-2-Z + O2CHO = C6H112-5-Z + HO2CHO
# Row 100/5990
# Reaction: C6H12-2-E + O2CHO = C6H112-5-E + HO2CHO
# Row 101/5990
# Reaction: IC6OOH2-3O2-A0 = IC6Q23-1-AA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH2-3O2-Ar = IC6Q23-1-AAr
#  - Missing enantiomer: IC6OOH2-3O2-A1 = IC6Q23-1-AA1
# Row 102/5990
# Reaction: IC6OOH2-3O2-A0 = IC6Q23-1-AB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH2-3O2-Ar = IC6Q23-1-ABr
#  - Missing enantiomer: IC6OOH2-3O2-A1 = IC6Q23-1-AB1
# Row 103/5990
# Reaction: NEC6D3 + OH = NEC6D3-1 + H2O
# Row 104/5990
# Reaction: C6H12OOH1-4O-A0 = NC4KET14 + C2H5
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH1-4O-Ar = NC4KET14 + C2H5
#  - Missing enantiomer: C6H12OOH1-4O-A1 = NC4KET14 + C2H5
# Row 105/5990
# Reaction: NC6H14 + O = C6H13-1 + OH
# Row 106/5990
# Reaction: C7H13Q23-5-AA0 = C7H13O35-2OOH-AAA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q23-5-AAr = C7H13O35-2OOH-AAAr + OH
#  - Missing enantiomer: C7H13Q23-5-AA1 = C7H13O35-2OOH-AAA1 + OH
# Row 107/5990
# Reaction: C7H13Q23-5-AB0 = C7H13O35-2OOH-AAB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q23-5-ABr = C7H13O35-2OOH-AABr + OH
#  - Missing enantiomer: C7H13Q23-5-AB1 = C7H13O35-2OOH-AAB1 + OH
# Row 108/5990
# Reaction: C7H13Q23-5-AB1 = C7H13O35-2OOH-ABB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q23-5-ABr = C7H13O35-2OOH-ABBr + OH
#  - Missing enantiomer: C7H13Q23-5-AB0 = C7H13O35-2OOH-ABB0 + OH
# Row 109/5990
# Reaction: C7H13Q23-5-AA1 = C7H13O35-2OOH-ABA1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q23-5-AAr = C7H13O35-2OOH-ABAr + OH
#  - Missing enantiomer: C7H13Q23-5-AA0 = C7H13O35-2OOH-ABA0 + OH
# Row 110/5990
# Reaction: C6KET12O-A1 = PC4H9CHO + HCO
#  - Reaction is chiral.
#  - Racemic name: C6KET12O-Ar = PC4H9CHO + HCO
#  - Missing enantiomer: C6KET12O-A0 = PC4H9CHO + HCO
# Row 111/5990
# Reaction: NC6D1KET53-A0 = NC6D1KET53O-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: NC6D1KET53-Ar = NC6D1KET53O-Ar + OH
#  - Missing enantiomer: NC6D1KET53-A1 = NC6D1KET53O-A1 + OH
# Row 112/5990
# Reaction: IC6Q24-3-A0 = IC6O34-2OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q24-3-Ar = IC6O34-2OOH-AAr + OH
#  - Missing enantiomer: IC6Q24-3-A1 = IC6O34-2OOH-AA1 + OH
# Row 113/5990
# Reaction: IC6Q24-3-A1 = IC6O34-2OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q24-3-Ar = IC6O34-2OOH-ABr + OH
#  - Missing enantiomer: IC6Q24-3-A0 = IC6O34-2OOH-AB0 + OH
# Row 114/5990
# Reaction: C7KET34-A0 = C7KET34O-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7KET34-Ar = C7KET34O-Ar + OH
#  - Missing enantiomer: C7KET34-A1 = C7KET34O-A1 + OH
# Row 115/5990
# Reaction: IC6D13-Z + OH = IC6D13-5R-ZZ + H2O
# Row 116/5990
# Reaction: IC6D13-Z + OH = IC6D13-5R-ZE + H2O
# Row 117/5990
# Reaction: IC6D13-E + OH = IC6D13-5R-EZ + H2O
# Row 118/5990
# Reaction: IC6D13-E + OH = IC6D13-5R-EE + H2O
# Row 119/5990
# Reaction: I3C6-4O2 = I3C6OOH4-3
# Row 120/5990
# Reaction: IC6OOH1-4-A0 = IC6O1-4-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-4-Ar = IC6O1-4-AAr + OH
#  - Missing enantiomer: IC6OOH1-4-A1 = IC6O1-4-AA1 + OH
# Row 121/5990
# Reaction: IC6OOH1-4-A1 = IC6O1-4-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-4-Ar = IC6O1-4-ABr + OH
#  - Missing enantiomer: IC6OOH1-4-A0 = IC6O1-4-AB0 + OH
# Row 122/5990
# Reaction: IC6OOH2-4 + O2 = IC6OOH2-4O2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH2-4 + O2 = IC6OOH2-4O2-Ar
#  - Missing enantiomer: IC6OOH2-4 + O2 = IC6OOH2-4O2-A1
# Row 123/5990
# Reaction: C7H14OOH3-6-A0 = C7H14O2-5-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-6-Ar = C7H14O2-5-AAr + OH
#  - Missing enantiomer: C7H14OOH3-6-A1 = C7H14O2-5-AA1 + OH
# Row 124/5990
# Reaction: C7H14OOH3-6-A1 = C7H14O2-5-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-6-Ar = C7H14O2-5-ABr + OH
#  - Missing enantiomer: C7H14OOH3-6-A0 = C7H14O2-5-AB1 + OH
# Row 125/5990
# Reaction: C7H121OOH6-3O2-AA0 = C7H11D13-6OOH-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH6-3O2-AAr = C7H11D13-6OOH-ZAr + HO2
#  - Missing enantiomer: C7H121OOH6-3O2-AA1 = C7H11D13-6OOH-ZA1 + HO2
# Row 126/5990
# Reaction: C7H121OOH6-3O2-AB1 = C7H11D13-6OOH-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH6-3O2-ABr = C7H11D13-6OOH-ZAr + HO2
#  - Missing enantiomer: C7H121OOH6-3O2-AB0 = C7H11D13-6OOH-ZA0 + HO2
# Row 127/5990
# Reaction: C7H121OOH6-3O2-AA0 = C7H11D13-6OOH-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH6-3O2-AAr = C7H11D13-6OOH-EAr + HO2
#  - Missing enantiomer: C7H121OOH6-3O2-AA1 = C7H11D13-6OOH-EA1 + HO2
# Row 128/5990
# Reaction: C7H121OOH6-3O2-AB1 = C7H11D13-6OOH-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH6-3O2-ABr = C7H11D13-6OOH-EAr + HO2
#  - Missing enantiomer: C7H121OOH6-3O2-AB0 = C7H11D13-6OOH-EA0 + HO2
# Row 129/5990
# Reaction: SC4H9CHO-A1 + CH3O = SC4H9CO-A1 + CH3OH
#  - Reaction is chiral.
#  - Racemic name: SC4H9CHO-Ar + CH3O = SC4H9CO-Ar + CH3OH
#  - Missing enantiomer: SC4H9CHO-A0 + CH3O = SC4H9CO-A0 + CH3OH
# Row 130/5990
# Reaction: I3C6OOH4-1-A0 = C2H4 + C4H8OOH1-2
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH4-1-Ar = C2H4 + C4H8OOH1-2
#  - Missing enantiomer: I3C6OOH4-1-A1 = C2H4 + C4H8OOH1-2
# Row 131/5990
# Reaction: C6H12OOH3-4-A1 + O2 = C6H12OOH3-4O2-AB0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-4-Ar + O2 = C6H12OOH3-4O2-ABr
#  - Missing enantiomer: C6H12OOH3-4-A0 + O2 = C6H12OOH3-4O2-AB1
# Row 132/5990
# Reaction: C6H12OOH3-4-A0 + O2 = C6H12OOH3-4O2-AA0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-4-Ar + O2 = C6H12OOH3-4O2-AAr
#  - Missing enantiomer: C6H12OOH3-4-A1 + O2 = C6H12OOH3-4O2-AA1
# Row 133/5990
# Reaction: C6H111O2-4-A1 = C6H10D13-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H111O2-4-Ar = C6H10D13-Z + HO2
#  - Missing enantiomer: C6H111O2-4-A0 = C6H10D13-Z + HO2
# Row 134/5990
# Reaction: C6H111O2-4-A0 = C6H10D13-E + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H111O2-4-Ar = C6H10D13-E + HO2
#  - Missing enantiomer: C6H111O2-4-A1 = C6H10D13-E + HO2
# Row 135/5990
# Reaction: C7H14OOH1-4O2-A0 = C7H13Q14-7-A0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH1-4O2-Ar = C7H13Q14-7-Ar
#  - Missing enantiomer: C7H14OOH1-4O2-A1 = C7H13Q14-7-A1
# Row 136/5990
# Reaction: IC6OOH1-1AO2-A0 = IC6D1-1AOOH + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-1AO2-Ar = IC6D1-1AOOH + HO2
#  - Missing enantiomer: IC6OOH1-1AO2-A1 = IC6D1-1AOOH + HO2
# Row 137/5990
# Reaction: XC6Q12-3-A0 = XC6D2-1OOH + HO2
#  - Reaction is chiral.
#  - Racemic name: XC6Q12-3-Ar = XC6D2-1OOH + HO2
#  - Missing enantiomer: XC6Q12-3-A1 = XC6D2-1OOH + HO2
# Row 138/5990
# Reaction: C4H71-3-Z + C2H5 = C4H8-1 + C2H4
# Row 139/5990
# Reaction: C4H71-3-E + C2H5 = C4H8-1 + C2H4
# Row 140/5990
# Reaction: C6KET13-A1 = C6KET13O-A1 + OH
#  - Reaction is chiral.
#  - Racemic name: C6KET13-Ar = C6KET13O-Ar + OH
#  - Missing enantiomer: C6KET13-A0 = C6KET13O-A0 + OH
# Row 141/5990
# Reaction: IC5H12 + C2H5 = CC5H11 + C2H6
# Row 142/5990
# Reaction: C7H13Q13-2-A1 = C7H13O12-3OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q13-2-Ar = C7H13O12-3OOH-ABr + OH
#  - Missing enantiomer: C7H13Q13-2-A0 = C7H13O12-3OOH-AB0 + OH
# Row 143/5990
# Reaction: C7H13Q13-2-A0 = C7H13O12-3OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q13-2-Ar = C7H13O12-3OOH-AAr + OH
#  - Missing enantiomer: C7H13Q13-2-A1 = C7H13O12-3OOH-AA1 + OH
# Row 144/5990
# Reaction: C7H13OH2Q1-4O2-AA0 = C7H124OH2Q1-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH2Q1-4O2-AAr = C7H124OH2Q1-EAr + HO2
#  - Missing enantiomer: C7H13OH2Q1-4O2-AA1 = C7H124OH2Q1-EA1 + HO2
# Row 145/5990
# Reaction: C7H13OH2Q1-4O2-AB0 = C7H124OH2Q1-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH2Q1-4O2-ABr = C7H124OH2Q1-ZAr + HO2
#  - Missing enantiomer: C7H13OH2Q1-4O2-AB1 = C7H124OH2Q1-ZA1 + HO2
# Row 146/5990
# Reaction: C7H13OH2Q1-4O2-AB1 = C7H124OH2Q1-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH2Q1-4O2-ABr = C7H124OH2Q1-EAr + HO2
#  - Missing enantiomer: C7H13OH2Q1-4O2-AB0 = C7H124OH2Q1-EA0 + HO2
# Row 147/5990
# Reaction: C7H13OH2Q1-4O2-AA1 = C7H124OH2Q1-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH2Q1-4O2-AAr = C7H124OH2Q1-ZAr + HO2
#  - Missing enantiomer: C7H13OH2Q1-4O2-AA0 = C7H124OH2Q1-ZA0 + HO2
# Row 148/5990
# Reaction: C6H12OH-3O2-2-AA0 = C6H11OH3Q2-5-AA0
#  - Reaction is chiral.
#  - Racemic name: C6H12OH-3O2-2-AAr = C6H11OH3Q2-5-AAr
#  - Missing enantiomer: C6H12OH-3O2-2-AA1 = C6H11OH3Q2-5-AA1
# Row 149/5990
# Reaction: C6H12OH-3O2-2-AB0 = C6H11OH3Q2-5-AB0
#  - Reaction is chiral.
#  - Racemic name: C6H12OH-3O2-2-ABr = C6H11OH3Q2-5-ABr
#  - Missing enantiomer: C6H12OH-3O2-2-AB1 = C6H11OH3Q2-5-AB1
# Row 150/5990
# Reaction: C6H12OH-3O2-2-AB1 = C6H11OH3Q2-5-AB1
#  - Reaction is chiral.
#  - Racemic name: C6H12OH-3O2-2-ABr = C6H11OH3Q2-5-ABr
#  - Missing enantiomer: C6H12OH-3O2-2-AB0 = C6H11OH3Q2-5-AB0
# Row 151/5990
# Reaction: C6H12OH-3O2-2-AA1 = C6H11OH3Q2-5-AA1
#  - Reaction is chiral.
#  - Racemic name: C6H12OH-3O2-2-AAr = C6H11OH3Q2-5-AAr
#  - Missing enantiomer: C6H12OH-3O2-2-AA0 = C6H11OH3Q2-5-AA0
# Row 152/5990
# Reaction: IC6D1 + O = IC6D1-4 + OH
# Row 153/5990
# Reaction: IC6D3-Z + O2 = IC6D4-3-Z + HO2
# Row 154/5990
# Reaction: IC6D3-E + O2 = IC6D4-3-E + HO2
# Row 155/5990
# Reaction: C6H11Q13-4-A0 = C6H11O14-3OOH-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q13-4-Ar = C6H11O14-3OOH-ABr + OH
#  - Missing enantiomer: C6H11Q13-4-A1 = C6H11O14-3OOH-AB1 + OH
# Row 156/5990
# Reaction: C6H11Q13-4-A1 = C6H11O14-3OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q13-4-Ar = C6H11O14-3OOH-AAr + OH
#  - Missing enantiomer: C6H11Q13-4-A0 = C6H11O14-3OOH-AA1 + OH
# Row 157/5990
# Reaction: IC5H12 + CH3O = DC5H11 + CH3OH
# Row 158/5990
# Reaction: C7H131-4 + O2 = C7H121-3-Z + HO2
# Row 159/5990
# Reaction: C7H131-4 + O2 = C7H121-3-E + HO2
# Row 160/5990
# Reaction: IC6 + CH3O = IC6-4 + CH3OH
# Row 161/5990
# Reaction: C6H111O2-1-Z = PC4H9CHO + HCO
# Row 162/5990
# Reaction: C6H111O2-1-E = PC4H9CHO + HCO
# Row 163/5990
# Reaction: IC6OH3-4J-A0 + O2 = IC6OH3-4O2-AB0
#  - Reaction is chiral.
#  - Racemic name: IC6OH3-4J-Ar + O2 = IC6OH3-4O2-ABr
#  - Missing enantiomer: IC6OH3-4J-A1 + O2 = IC6OH3-4O2-AB1
# Row 164/5990
# Reaction: IC6OH3-4J-A1 + O2 = IC6OH3-4O2-AA0
#  - Reaction is chiral.
#  - Racemic name: IC6OH3-4J-Ar + O2 = IC6OH3-4O2-AAr
#  - Missing enantiomer: IC6OH3-4J-A0 + O2 = IC6OH3-4O2-AA1
# Row 165/5990
# Reaction: C7KET31O = CH2O + C6Y2-1J
# Row 166/5990
# Reaction: XC6OOH2-1-A0 + O2 = XC6OOH2-1O2-A1
#  - Reaction is chiral.
#  - Racemic name: XC6OOH2-1-Ar + O2 = XC6OOH2-1O2-Ar
#  - Missing enantiomer: XC6OOH2-1-A1 + O2 = XC6OOH2-1O2-A0
# Row 167/5990
# Reaction: I3C6D1-A0 + OH = I3C6D1-5-A0 + H2O
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-Ar + OH = I3C6D1-5-Ar + H2O
#  - Missing enantiomer: I3C6D1-A1 + OH = I3C6D1-5-A1 + H2O
# Row 168/5990
# Reaction: I3C6D1-A1 + OH = I3C6D1-5-A1 + H2O
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-Ar + OH = I3C6D1-5-Ar + H2O
#  - Missing enantiomer: I3C6D1-A0 + OH = I3C6D1-5-A0 + H2O
# Row 169/5990
# Reaction: IC6D2-5 = IC4H7-I1 + C2H4
# Row 170/5990
# Reaction: IC6Q24-5-A0 = IC6O45-2OOH-A1 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q24-5-Ar = IC6O45-2OOH-Ar + OH
#  - Missing enantiomer: IC6Q24-5-A1 = IC6O45-2OOH-A0 + OH
# Row 171/5990
# Reaction: C6H12-1 + CH3 = C6H111-1-E + CH4
# Row 172/5990
# Reaction: C6H12-1 + CH3 = C6H111-1-Z + CH4
# Row 173/5990
# Reaction: C6H6 + HO2 = C6H5 + H2O2
# Row 174/5990
# Reaction: XC6OOH1-4-AA1 = C5H9C-AOOH-A0 + CH3
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4-AAr = C5H9C-AOOH-Ar + CH3
#  - Missing enantiomer: XC6OOH1-4-AA0 = C5H9C-AOOH-A1 + CH3
# Row 175/5990
# Reaction: XC6OOH1-4-AB1 = C5H9C-AOOH-A1 + CH3
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4-ABr = C5H9C-AOOH-Ar + CH3
#  - Missing enantiomer: XC6OOH1-4-AB0 = C5H9C-AOOH-A0 + CH3
# Row 176/5990
# Reaction: IC6OOH1-2 + O2 = IC6OOH1-2O2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-2 + O2 = IC6OOH1-2O2-Ar
#  - Missing enantiomer: IC6OOH1-2 + O2 = IC6OOH1-2O2-A1
# Row 177/5990
# Reaction: IC6OOH2-5 = C2H4 + TC4H8O2H-I
# Row 178/5990
# Reaction: C3H5-A + C3H5-A(+M) = C6H101-5(+M)
# Row 179/5990
# Reaction: XC6OOH2-1O2-A0 = XC6Q12-1A-A0
#  - Reaction is chiral.
#  - Racemic name: XC6OOH2-1O2-Ar = XC6Q12-1A-Ar
#  - Missing enantiomer: XC6OOH2-1O2-A1 = XC6Q12-1A-A1
# Row 180/5990
# Reaction: C7H14-1 + O = C7H131-3-Z + OH
# Row 181/5990
# Reaction: C7H14-1 + O = C7H131-3-E + OH
# Row 182/5990
# Reaction: C5H11-3 + CH3 = I3C6
# Row 183/5990
# Reaction: IC5Y3 + CH3O2 = IC5Y3-2J + CH3O2H
# Row 184/5990
# Reaction: C6H12OOH3-5O2-AA0 = C6H11Q24-5-AA0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-5O2-AAr = C6H11Q24-5-AAr
#  - Missing enantiomer: C6H12OOH3-5O2-AA1 = C6H11Q24-5-AA1
# Row 185/5990
# Reaction: C6H12OOH3-5O2-AB0 = C6H11Q24-5-AB0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-5O2-ABr = C6H11Q24-5-ABr
#  - Missing enantiomer: C6H12OOH3-5O2-AB1 = C6H11Q24-5-AB1
# Row 186/5990
# Reaction: C6H12OOH3-5O2-AB1 = C6H11Q24-5-AB1
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-5O2-ABr = C6H11Q24-5-ABr
#  - Missing enantiomer: C6H12OOH3-5O2-AB0 = C6H11Q24-5-AB0
# Row 187/5990
# Reaction: C6H12OOH3-5O2-AA1 = C6H11Q24-5-AA1
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-5O2-AAr = C6H11Q24-5-AAr
#  - Missing enantiomer: C6H12OOH3-5O2-AA0 = C6H11Q24-5-AA0
# Row 188/5990
# Reaction: C7H14-1 + O = C7H131-2 + OH
# Row 189/5990
# Reaction: C7H15-4 + O2 = C7H14-3-Z + HO2
# Row 190/5990
# Reaction: C7H15-4 + O2 = C7H14-3-E + HO2
# Row 191/5990
# Reaction: IC6D2 + CH3O2 = IC6D3-2-Z + CH3O2H
# Row 192/5990
# Reaction: IC6D2 + CH3O2 = IC6D3-2-E + CH3O2H
# Row 193/5990
# Reaction: IC6 + O = IC6-3 + OH
# Row 194/5990
# Reaction: XC6OH2-3J + O2 = XC6OH2-3O2
# Row 195/5990
# Reaction: IC5Y3 + CH3O2 = IC5Y3-1J-A0 + CH3O2H
#  - Reaction is chiral.
#  - Racemic name: IC5Y3 + CH3O2 = IC5Y3-1J-Ar + CH3O2H
#  - Missing enantiomer: IC5Y3 + CH3O2 = IC5Y3-1J-A1 + CH3O2H
# Row 196/5990
# Reaction: I3C6D1-A0 + OH = I3C6D1-6-A0 + H2O
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-Ar + OH = I3C6D1-6-Ar + H2O
#  - Missing enantiomer: I3C6D1-A1 + OH = I3C6D1-6-A1 + H2O
# Row 197/5990
# Reaction: I3C6-2-A0 = C5H10-2-Z + CH3
#  - Reaction is chiral.
#  - Racemic name: I3C6-2-Ar = C5H10-2-Z + CH3
#  - Missing enantiomer: I3C6-2-A1 = C5H10-2-Z + CH3
# Row 198/5990
# Reaction: I3C6-2-A0 = C5H10-2-E + CH3
#  - Reaction is chiral.
#  - Racemic name: I3C6-2-Ar = C5H10-2-E + CH3
#  - Missing enantiomer: I3C6-2-A1 = C5H10-2-E + CH3
# Row 199/5990
# Reaction: C7H121OOH5-3O2-AB0 = C7H11D13-5OOH-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3O2-ABr = C7H11D13-5OOH-ZAr + HO2
#  - Missing enantiomer: C7H121OOH5-3O2-AB1 = C7H11D13-5OOH-ZA0 + HO2
# Row 200/5990
# Reaction: C7H121OOH5-3O2-AA0 = C7H11D13-5OOH-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3O2-AAr = C7H11D13-5OOH-ZAr + HO2
#  - Missing enantiomer: C7H121OOH5-3O2-AA1 = C7H11D13-5OOH-ZA1 + HO2
# Row 201/5990
# Reaction: C7H121OOH5-3O2-AB0 = C7H11D13-5OOH-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3O2-ABr = C7H11D13-5OOH-EAr + HO2
#  - Missing enantiomer: C7H121OOH5-3O2-AB1 = C7H11D13-5OOH-EA0 + HO2
# Row 202/5990
# Reaction: C7H121OOH5-3O2-AA0 = C7H11D13-5OOH-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3O2-AAr = C7H11D13-5OOH-EAr + HO2
#  - Missing enantiomer: C7H121OOH5-3O2-AA1 = C7H11D13-5OOH-EA1 + HO2
# Row 203/5990
# Reaction: C7H13Q13-4-A0 = C7H13O34-1OOH-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q13-4-Ar = C7H13O34-1OOH-ABr + OH
#  - Missing enantiomer: C7H13Q13-4-A1 = C7H13O34-1OOH-AB1 + OH
# Row 204/5990
# Reaction: C7H13Q13-4-A1 = C7H13O34-1OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q13-4-Ar = C7H13O34-1OOH-AAr + OH
#  - Missing enantiomer: C7H13Q13-4-A0 = C7H13O34-1OOH-AA1 + OH
# Row 205/5990
# Reaction: C7H14OOH3-1O-A1 = CH2O + C6H12OOH2-1-A0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-1O-Ar = CH2O + C6H12OOH2-1-Ar
#  - Missing enantiomer: C7H14OOH3-1O-A0 = CH2O + C6H12OOH2-1-A1
# Row 206/5990
# Reaction: C7H121OOH4-5-A1 = C7H121-4-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH4-5-Ar = C7H121-4-Z + HO2
#  - Missing enantiomer: C7H121OOH4-5-A0 = C7H121-4-Z + HO2
# Row 207/5990
# Reaction: C7H121OOH4-5-A1 = C7H121-4-E + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH4-5-Ar = C7H121-4-E + HO2
#  - Missing enantiomer: C7H121OOH4-5-A0 = C7H121-4-E + HO2
# Row 208/5990
# Reaction: C7H121OOH4-6-A0 = C7H121O4-6-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH4-6-Ar = C7H121O4-6-AAr + OH
#  - Missing enantiomer: C7H121OOH4-6-A1 = C7H121O4-6-AA1 + OH
# Row 209/5990
# Reaction: C7H121OOH4-6-A1 = C7H121O4-6-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH4-6-Ar = C7H121O4-6-ABr + OH
#  - Missing enantiomer: C7H121OOH4-6-A0 = C7H121O4-6-AB1 + OH
# Row 210/5990
# Reaction: C6H111O2-5-A0 = C6H101OOH5-6-A0
#  - Reaction is chiral.
#  - Racemic name: C6H111O2-5-Ar = C6H101OOH5-6-Ar
#  - Missing enantiomer: C6H111O2-5-A1 = C6H101OOH5-6-A1
# Row 211/5990
# Reaction: IC6D1 + CH3O2 = IC6D1-5 + CH3O2H
# Row 212/5990
# Reaction: IC6OOH4-3O2-AA0 = IC6Q34-1-AAA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-3O2-AAr = IC6Q34-1-AAAr
#  - Missing enantiomer: IC6OOH4-3O2-AA1 = IC6Q34-1-AAA1
# Row 213/5990
# Reaction: IC6OOH4-3O2-AB0 = IC6Q34-1-AAB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-3O2-ABr = IC6Q34-1-AABr
#  - Missing enantiomer: IC6OOH4-3O2-AB1 = IC6Q34-1-AAB1
# Row 214/5990
# Reaction: IC6OOH4-3O2-AB1 = IC6Q34-1-ABA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-3O2-ABr = IC6Q34-1-ABAr
#  - Missing enantiomer: IC6OOH4-3O2-AB0 = IC6Q34-1-ABA1
# Row 215/5990
# Reaction: IC6OOH4-3O2-AA1 = IC6Q34-1-ABB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-3O2-AAr = IC6Q34-1-ABBr
#  - Missing enantiomer: IC6OOH4-3O2-AA0 = IC6Q34-1-ABB1
# Row 216/5990
# Reaction: NC6H14 + H = C6H13-3 + H2
# Row 217/5990
# Reaction: HOC6H4CH3 + O = HOC6H4CH2 + OH
# Row 218/5990
# Reaction: I3C6OOH2-6O2-AA0 = I3C6Q15-2-AA0
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH2-6O2-AAr = I3C6Q15-2-AAr
#  - Missing enantiomer: I3C6OOH2-6O2-AA1 = I3C6Q15-2-AA1
# Row 219/5990
# Reaction: I3C6OOH2-6O2-AB0 = I3C6Q15-2-AB0
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH2-6O2-ABr = I3C6Q15-2-ABr
#  - Missing enantiomer: I3C6OOH2-6O2-AB1 = I3C6Q15-2-AB1
# Row 220/5990
# Reaction: I3C6OOH2-6O2-AB1 = I3C6Q15-2-AB1
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH2-6O2-ABr = I3C6Q15-2-ABr
#  - Missing enantiomer: I3C6OOH2-6O2-AB0 = I3C6Q15-2-AB0
# Row 221/5990
# Reaction: I3C6OOH2-6O2-AA1 = I3C6Q15-2-AA1
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH2-6O2-AAr = I3C6Q15-2-AAr
#  - Missing enantiomer: I3C6OOH2-6O2-AA0 = I3C6Q15-2-AA0
# Row 222/5990
# Reaction: C6H12OH-1J2 + O2 = C6H12OH-1O2-2-A0
#  - Reaction is chiral.
#  - Racemic name: C6H12OH-1J2 + O2 = C6H12OH-1O2-2-Ar
#  - Missing enantiomer: C6H12OH-1J2 + O2 = C6H12OH-1O2-2-A1
# Row 223/5990
# Reaction: C5H5CH3-1 = C5H5CH2-1 + H
# Row 224/5990
# Reaction: IC6-3 = IC6D2 + H
# Row 225/5990
# Reaction: C7H121OOH4-5-A1 = C7H121O4-5-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH4-5-Ar = C7H121O4-5-ABr + OH
#  - Missing enantiomer: C7H121OOH4-5-A0 = C7H121O4-5-AB1 + OH
# Row 226/5990
# Reaction: C7H121OOH4-5-A0 = C7H121O4-5-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH4-5-Ar = C7H121O4-5-AAr + OH
#  - Missing enantiomer: C7H121OOH4-5-A1 = C7H121O4-5-AA1 + OH
# Row 227/5990
# Reaction: I3C6-1O2-A0 = I3C6OOH1-5-A0
#  - Reaction is chiral.
#  - Racemic name: I3C6-1O2-Ar = I3C6OOH1-5-Ar
#  - Missing enantiomer: I3C6-1O2-A1 = I3C6OOH1-5-A1
# Row 228/5990
# Reaction: I3C6-1O2-A1 = I3C6OOH1-5-A1
#  - Reaction is chiral.
#  - Racemic name: I3C6-1O2-Ar = I3C6OOH1-5-Ar
#  - Missing enantiomer: I3C6-1O2-A0 = I3C6OOH1-5-A0
# Row 229/5990
# Reaction: C7H13OH1Q2-3O2-AB0 = C7H123OH1Q2-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH1Q2-3O2-ABr = C7H123OH1Q2-EAr + HO2
#  - Missing enantiomer: C7H13OH1Q2-3O2-AB1 = C7H123OH1Q2-EA1 + HO2
# Row 230/5990
# Reaction: C7H13OH1Q2-3O2-AA0 = C7H123OH1Q2-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH1Q2-3O2-AAr = C7H123OH1Q2-EAr + HO2
#  - Missing enantiomer: C7H13OH1Q2-3O2-AA1 = C7H123OH1Q2-EA0 + HO2
# Row 231/5990
# Reaction: C7H13OH1Q2-3O2-AA1 = C7H123OH1Q2-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH1Q2-3O2-AAr = C7H123OH1Q2-ZAr + HO2
#  - Missing enantiomer: C7H13OH1Q2-3O2-AA0 = C7H123OH1Q2-ZA1 + HO2
# Row 232/5990
# Reaction: C7H13OH1Q2-3O2-AB1 = C7H123OH1Q2-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H13OH1Q2-3O2-ABr = C7H123OH1Q2-ZAr + HO2
#  - Missing enantiomer: C7H13OH1Q2-3O2-AB0 = C7H123OH1Q2-ZA0 + HO2
# Row 233/5990
# Reaction: IC6Q24-5-A0 = IC6O25-4OOH-A1 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q24-5-Ar = IC6O25-4OOH-Ar + OH
#  - Missing enantiomer: IC6Q24-5-A1 = IC6O25-4OOH-A0 + OH
# Row 234/5990
# Reaction: NC6D1KET65O-A1 = C4H7CHO-4 + HCO
#  - Reaction is chiral.
#  - Racemic name: NC6D1KET65O-Ar = C4H7CHO-4 + HCO
#  - Missing enantiomer: NC6D1KET65O-A0 = C4H7CHO-4 + HCO
# Row 235/5990
# Reaction: C6H11Q24-3-AB0 = C6H11-2D4OOH-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q24-3-ABr = C6H11-2D4OOH-ZAr + HO2
#  - Missing enantiomer: C6H11Q24-3-AB1 = C6H11-2D4OOH-ZA0 + HO2
# Row 236/5990
# Reaction: C6H11Q24-3-AB0 = C6H11-2D4OOH-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q24-3-ABr = C6H11-2D4OOH-EAr + HO2
#  - Missing enantiomer: C6H11Q24-3-AB1 = C6H11-2D4OOH-EA0 + HO2
# Row 237/5990
# Reaction: C6H11Q24-3-AA0 = C6H11-2D4OOH-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q24-3-AAr = C6H11-2D4OOH-ZAr + HO2
#  - Missing enantiomer: C6H11Q24-3-AA1 = C6H11-2D4OOH-ZA1 + HO2
# Row 238/5990
# Reaction: C6H11Q24-3-AA0 = C6H11-2D4OOH-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q24-3-AAr = C6H11-2D4OOH-EAr + HO2
#  - Missing enantiomer: C6H11Q24-3-AA1 = C6H11-2D4OOH-EA1 + HO2
# Row 239/5990
# Reaction: IC6D4 + CH3O2 = IC6D4-2 + CH3O2H
# Row 240/5990
# Reaction: C6H11Q34-1-AA0 = C6H11O13-4OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q34-1-AAr = C6H11O13-4OOH-AAr + OH
#  - Missing enantiomer: C6H11Q34-1-AA1 = C6H11O13-4OOH-AA1 + OH
# Row 241/5990
# Reaction: C6H11Q34-1-AB0 = C6H11O13-4OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q34-1-ABr = C6H11O13-4OOH-ABr + OH
#  - Missing enantiomer: C6H11Q34-1-AB1 = C6H11O13-4OOH-AB0 + OH
# Row 242/5990
# Reaction: C7H15OOH-4 + O2 = C7H15-4O2 + HO2
# Row 243/5990
# Reaction: C7H14-1 + H = C7H15-2
# Row 244/5990
# Reaction: I3C6KET4-3 = I3C6KET4-3O + OH
# Row 245/5990
# Reaction: C6H5OO = C6H5O + O
# Row 246/5990
# Reaction: H + FULVENE = C5H5CH2
# Row 247/5990
# Reaction: C5H4CH3 = FULVENE + H
# Row 248/5990
# Reaction: I3C6OOH1-3O2-A1 = I3C6D2-1OOH-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH1-3O2-Ar = I3C6D2-1OOH-Z + HO2
#  - Missing enantiomer: I3C6OOH1-3O2-A0 = I3C6D2-1OOH-Z + HO2
# Row 249/5990
# Reaction: I3C6OOH1-3O2-A0 = I3C6D2-1OOH-E + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6OOH1-3O2-Ar = I3C6D2-1OOH-E + HO2
#  - Missing enantiomer: I3C6OOH1-3O2-A1 = I3C6D2-1OOH-E + HO2
# Row 250/5990
# Reaction: IC6-4 + H = IC6
# Row 251/5990
# Reaction: IC6 + CH3O = IC6-2 + CH3OH
# Row 252/5990
# Reaction: NEC6 + O = NEC6-3 + OH
# Row 253/5990
# Reaction: IC6OOH4-1O2-AA0 = IC6Q14-2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-1O2-AAr = IC6Q14-2-Ar
#  - Missing enantiomer: IC6OOH4-1O2-AA1 = IC6Q14-2-A1
# Row 254/5990
# Reaction: IC6OOH4-1O2-AB0 = IC6Q14-2-A1
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-1O2-ABr = IC6Q14-2-Ar
#  - Missing enantiomer: IC6OOH4-1O2-AB1 = IC6Q14-2-A0
# Row 255/5990
# Reaction: I3C6Q13-6-A0 = I3C6O16-3OOH + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q13-6-Ar = I3C6O16-3OOH + OH
#  - Missing enantiomer: I3C6Q13-6-A1 = I3C6O16-3OOH + OH
# Row 256/5990
# Reaction: IC6D1 + CH3 = IC6D1-1A + CH4
# Row 257/5990
# Reaction: HOC6H4CH2 + HO2 = HOC6H4CH2OOH
# Row 258/5990
# Reaction: IC6KET3-1-A0 = IC6KET3-1O-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6KET3-1-Ar = IC6KET3-1O-Ar + OH
#  - Missing enantiomer: IC6KET3-1-A1 = IC6KET3-1O-A1 + OH
# Row 259/5990
# Reaction: C6H101OOH3-6-A0 = VTHF-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH3-6-Ar = VTHF-Ar + OH
#  - Missing enantiomer: C6H101OOH3-6-A1 = VTHF-A1 + OH
# Row 260/5990
# Reaction: NC3H7CHO + C2H5CO3 = NC3H7CO + C2H5CO3H
# Row 261/5990
# Reaction: C6H101OOH5-4-A0 + O2 = C6H101OOH5-4O2-AA0
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH5-4-Ar + O2 = C6H101OOH5-4O2-AAr
#  - Missing enantiomer: C6H101OOH5-4-A1 + O2 = C6H101OOH5-4O2-AA1
# Row 262/5990
# Reaction: C6H101OOH5-4-A1 + O2 = C6H101OOH5-4O2-AB1
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH5-4-Ar + O2 = C6H101OOH5-4O2-ABr
#  - Missing enantiomer: C6H101OOH5-4-A0 + O2 = C6H101OOH5-4O2-AB0
# Row 263/5990
# Reaction: C7H13Q25-6-AA0 = C7H13O26-3OOH-AAB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q25-6-AAr = C7H13O26-3OOH-AABr + OH
#  - Missing enantiomer: C7H13Q25-6-AA1 = C7H13O26-3OOH-AAB1 + OH
# Row 264/5990
# Reaction: C7H13Q25-6-AB0 = C7H13O26-3OOH-AAA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q25-6-ABr = C7H13O26-3OOH-AAAr + OH
#  - Missing enantiomer: C7H13Q25-6-AB1 = C7H13O26-3OOH-AAA1 + OH
# Row 265/5990
# Reaction: C7H13Q25-6-AB1 = C7H13O26-3OOH-ABA1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q25-6-ABr = C7H13O26-3OOH-ABAr + OH
#  - Missing enantiomer: C7H13Q25-6-AB0 = C7H13O26-3OOH-ABA0 + OH
# Row 266/5990
# Reaction: C7H13Q25-6-AA1 = C7H13O26-3OOH-ABB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H13Q25-6-AAr = C7H13O26-3OOH-ABBr + OH
#  - Missing enantiomer: C7H13Q25-6-AA0 = C7H13O26-3OOH-ABB0 + OH
# Row 267/5990
# Reaction: C6H11OH3Q2-3O2-AB0 = C6KET32-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11OH3Q2-3O2-ABr = C6KET32-Ar + HO2
#  - Missing enantiomer: C6H11OH3Q2-3O2-AB1 = C6KET32-A1 + HO2
# Row 268/5990
# Reaction: C6H11OH3Q2-3O2-AA1 = C6KET32-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11OH3Q2-3O2-AAr = C6KET32-Ar + HO2
#  - Missing enantiomer: C6H11OH3Q2-3O2-AA0 = C6KET32-A0 + HO2
# Row 269/5990
# Reaction: C7H121-3-Z + H = CVCCJCVCCC-ZZZ + H2
# Row 270/5990
# Reaction: C7H121-3-Z + H = CVCCJCVCCC-ZZE + H2
# Row 271/5990
# Reaction: C7H121-3-E + H = CVCCJCVCCC-ZEZ + H2
# Row 272/5990
# Reaction: C7H121-3-E + H = CVCCJCVCCC-ZEE + H2
# Row 273/5990
# Reaction: C7H121-3-Z + H = CVCCJCVCCC-EZZ + H2
# Row 274/5990
# Reaction: C7H121-3-Z + H = CVCCJCVCCC-EZE + H2
# Row 275/5990
# Reaction: C7H121-3-E + H = CVCCJCVCCC-EEZ + H2
# Row 276/5990
# Reaction: C7H121-3-E + H = CVCCJCVCCC-EEE + H2
# Row 277/5990
# Reaction: C7H121OOH5-3-ZA0 + HO2 = C7H121-3,5OOH-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3-ZAr + HO2 = C7H121-3,5OOH-AAr
#  - Missing enantiomer: C7H121OOH5-3-ZA1 + HO2 = C7H121-3,5OOH-AA1
# Row 278/5990
# Reaction: C7H121OOH5-3-EA0 + HO2 = C7H121-3,5OOH-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3-EAr + HO2 = C7H121-3,5OOH-AAr
#  - Missing enantiomer: C7H121OOH5-3-EA1 + HO2 = C7H121-3,5OOH-AA1
# Row 279/5990
# Reaction: C7H121OOH5-3-ZA1 + HO2 = C7H121-3,5OOH-AB0
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3-ZAr + HO2 = C7H121-3,5OOH-ABr
#  - Missing enantiomer: C7H121OOH5-3-ZA0 + HO2 = C7H121-3,5OOH-AB1
# Row 280/5990
# Reaction: C7H121OOH5-3-EA1 + HO2 = C7H121-3,5OOH-AB0
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH5-3-EAr + HO2 = C7H121-3,5OOH-ABr
#  - Missing enantiomer: C7H121OOH5-3-EA0 + HO2 = C7H121-3,5OOH-AB1
# Row 281/5990
# Reaction: IC6-4 + O2 = IC6-4O2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6-4 + O2 = IC6-4O2-Ar
#  - Missing enantiomer: IC6-4 + O2 = IC6-4O2-A1
# Row 282/5990
# Reaction: I3C6D2-Z + O2CHO = I3C6D1-3-Z + HO2CHO
# Row 283/5990
# Reaction: I3C6D2-E + O2CHO = I3C6D1-3-E + HO2CHO
# Row 284/5990
# Reaction: PC4H9O2 + CH3CHO = PC4H9O2H + CH3CO
# Row 285/5990
# Reaction: NC6H14 + O2CHO = C6H13-2 + HO2CHO
# Row 286/5990
# Reaction: C7H121OOH3-4-A0 + O2 = C7H121OOH3-4O2-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH3-4-Ar + O2 = C7H121OOH3-4O2-AAr
#  - Missing enantiomer: C7H121OOH3-4-A1 + O2 = C7H121OOH3-4O2-AA1
# Row 287/5990
# Reaction: C7H121OOH3-4-A1 + O2 = C7H121OOH3-4O2-AB1
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH3-4-Ar + O2 = C7H121OOH3-4O2-ABr
#  - Missing enantiomer: C7H121OOH3-4-A0 + O2 = C7H121OOH3-4O2-AB0
# Row 288/5990
# Reaction: XC6OOH1-4O2-AB0 = XC6D1-4OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4O2-ABr = XC6D1-4OOH-Ar + HO2
#  - Missing enantiomer: XC6OOH1-4O2-AB1 = XC6D1-4OOH-A1 + HO2
# Row 289/5990
# Reaction: XC6OOH1-4O2-AA1 = XC6D1-4OOH-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4O2-AAr = XC6D1-4OOH-Ar + HO2
#  - Missing enantiomer: XC6OOH1-4O2-AA0 = XC6D1-4OOH-A0 + HO2
# Row 290/5990
# Reaction: C6H11OH1Q2-5-A0 = QC3H5OHP-A0 + C3H6
#  - Reaction is chiral.
#  - Racemic name: C6H11OH1Q2-5-Ar = QC3H5OHP-Ar + C3H6
#  - Missing enantiomer: C6H11OH1Q2-5-A1 = QC3H5OHP-A1 + C3H6
# Row 291/5990
# Reaction: IC5H12 + C2H5 = DC5H11 + C2H6
# Row 292/5990
# Reaction: AC5H10 + CH3 = AC5H9-C-Z + CH4
# Row 293/5990
# Reaction: AC5H10 + CH3 = AC5H9-C-E + CH4
# Row 294/5990
# Reaction: HOC6H4CHO + OH = HOC6H4CO + H2O
# Row 295/5990
# Reaction: I3C6D1-A0 + CH3O2 = I3C6D1-4-A0 + CH3O2H
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-Ar + CH3O2 = I3C6D1-4-Ar + CH3O2H
#  - Missing enantiomer: I3C6D1-A1 + CH3O2 = I3C6D1-4-A1 + CH3O2H
# Row 296/5990
# Reaction: XC6OOH1-4-AA0 + O2 = XC6D1-4OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4-AAr + O2 = XC6D1-4OOH-Ar + HO2
#  - Missing enantiomer: XC6OOH1-4-AA1 + O2 = XC6D1-4OOH-A1 + HO2
# Row 297/5990
# Reaction: XC6OOH1-4-AB0 + O2 = XC6D1-4OOH-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4-ABr + O2 = XC6D1-4OOH-Ar + HO2
#  - Missing enantiomer: XC6OOH1-4-AB1 + O2 = XC6D1-4OOH-A0 + HO2
# Row 298/5990
# Reaction: I3C6Q13-4-A0 = I3C6O34-1OOH-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q13-4-Ar = I3C6O34-1OOH-Ar + OH
#  - Missing enantiomer: I3C6Q13-4-A1 = I3C6O34-1OOH-A1 + OH
# Row 299/5990
# Reaction: IC5H12 + CH3 = BC5H11 + CH4
# Row 300/5990
# Reaction: IC6OOH3-5-A0 + O2 = IC6OOH3-5O2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-5-Ar + O2 = IC6OOH3-5O2-Ar
#  - Missing enantiomer: IC6OOH3-5-A1 + O2 = IC6OOH3-5O2-A1
# Row 301/5990
# Reaction: I3C6D2-Z + HO2 = I3C6D2-5-ZZ + H2O2
# Row 302/5990
# Reaction: I3C6D2-Z + HO2 = I3C6D2-5-ZE + H2O2
# Row 303/5990
# Reaction: I3C6D2-E + HO2 = I3C6D2-5-ZE + H2O2
# Row 304/5990
# Reaction: I3C6D2-E + HO2 = I3C6D2-5-EE + H2O2
# Row 305/5990
# Reaction: IC6OOH5-2O2 = IC6Q25-1-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH5-2O2 = IC6Q25-1-Ar
#  - Missing enantiomer: IC6OOH5-2O2 = IC6Q25-1-A1
# Row 306/5990
# Reaction: IC6OOH4-2O2-A0 = IC6D2-4OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-2O2-Ar = IC6D2-4OOH-Ar + HO2
#  - Missing enantiomer: IC6OOH4-2O2-A1 = IC6D2-4OOH-A1 + HO2
# Row 307/5990
# Reaction: IC6OOH4-2O2-A1 = IC6D2-4OOH-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-2O2-Ar = IC6D2-4OOH-Ar + HO2
#  - Missing enantiomer: IC6OOH4-2O2-A0 = IC6D2-4OOH-A0 + HO2
# Row 308/5990
# Reaction: IC6OOH5-1-A0 + O2 = IC6OOH5-1O2-A0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH5-1-Ar + O2 = IC6OOH5-1O2-Ar
#  - Missing enantiomer: IC6OOH5-1-A1 + O2 = IC6OOH5-1O2-A1
# Row 309/5990
# Reaction: XC6OOH1-1A-A0 + O2 = XC6OOH1-1AO2-A0
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-1A-Ar + O2 = XC6OOH1-1AO2-Ar
#  - Missing enantiomer: XC6OOH1-1A-A1 + O2 = XC6OOH1-1AO2-A1
# Row 310/5990
# Reaction: C6H111O2-4-A0 = C6H101OOH4-2-A0
#  - Reaction is chiral.
#  - Racemic name: C6H111O2-4-Ar = C6H101OOH4-2-Ar
#  - Missing enantiomer: C6H111O2-4-A1 = C6H101OOH4-2-A1
# Row 311/5990
# Reaction: C5H5CH3 = C5H5CH3-1
# Row 312/5990
# Reaction: C5H5CH3 = C5H5CH3-1
# Row 313/5990
# Reaction: C7H14OOH2-6O2-AA0 = C7H13Q26-3-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH2-6O2-AAr = C7H13Q26-3-AAr
#  - Missing enantiomer: C7H14OOH2-6O2-AA1 = C7H13Q26-3-AA1
# Row 314/5990
# Reaction: C7H14OOH2-6O2-AB0 = C7H13Q26-3-AB1
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH2-6O2-ABr = C7H13Q26-3-ABr
#  - Missing enantiomer: C7H14OOH2-6O2-AB1 = C7H13Q26-3-AB0
# Row 315/5990
# Reaction: C7H14OOH2-6O2-AB1 = C7H13Q26-3-AB0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH2-6O2-ABr = C7H13Q26-3-ABr
#  - Missing enantiomer: C7H14OOH2-6O2-AB0 = C7H13Q26-3-AB1
# Row 316/5990
# Reaction: C7H14OOH2-6O2-AA1 = C7H13Q26-3-AA1
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH2-6O2-AAr = C7H13Q26-3-AAr
#  - Missing enantiomer: C7H14OOH2-6O2-AA0 = C7H13Q26-3-AA0
# Row 317/5990
# Reaction: SC4H9O2-A0 + C3H8 = SC4H9O2H-A0 + NC3H7
#  - Reaction is chiral.
#  - Racemic name: SC4H9O2-Ar + C3H8 = SC4H9O2H-Ar + NC3H7
#  - Missing enantiomer: SC4H9O2-A1 + C3H8 = SC4H9O2H-A1 + NC3H7
# Row 318/5990
# Reaction: IC6D4 + O2 = IC6D4-1-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: IC6D4 + O2 = IC6D4-1-Ar + HO2
#  - Missing enantiomer: IC6D4 + O2 = IC6D4-1-A1 + HO2
# Row 319/5990
# Reaction: C6H4CH3 + H(+M) = C6H5CH3(+M)
# Row 320/5990
# Reaction: CYPENTN-4MJ = H + CYPENTN-4MTHNE
# Row 321/5990
# Reaction: IC6KET1-1A-A1 = IC6KET1-1AO-A1 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6KET1-1A-Ar = IC6KET1-1AO-Ar + OH
#  - Missing enantiomer: IC6KET1-1A-A0 = IC6KET1-1AO-A0 + OH
# Row 322/5990
# Reaction: NC6H14 + H = C6H13-1 + H2
# Row 323/5990
# Reaction: C7H131-7O2 = C7H121OOH7-6
# Row 324/5990
# Reaction: C7H14OOH2-3-A0 + O2 = C7H14OOH2-3O2-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH2-3-Ar + O2 = C7H14OOH2-3O2-AAr
#  - Missing enantiomer: C7H14OOH2-3-A1 + O2 = C7H14OOH2-3O2-AA1
# Row 325/5990
# Reaction: C7H14OOH2-3-A1 + O2 = C7H14OOH2-3O2-AB1
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH2-3-Ar + O2 = C7H14OOH2-3O2-ABr
#  - Missing enantiomer: C7H14OOH2-3-A0 + O2 = C7H14OOH2-3O2-AB0
# Row 326/5990
# Reaction: C6H11Q23-1-AB0 = C6H11-1D3OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q23-1-ABr = C6H11-1D3OOH-Ar + HO2
#  - Missing enantiomer: C6H11Q23-1-AB1 = C6H11-1D3OOH-A1 + HO2
# Row 327/5990
# Reaction: C6H11Q23-1-AA0 = C6H11-1D3OOH-A1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H11Q23-1-AAr = C6H11-1D3OOH-Ar + HO2
#  - Missing enantiomer: C6H11Q23-1-AA1 = C6H11-1D3OOH-A0 + HO2
# Row 328/5990
# Reaction: C7H14-3-Z + O = C7H133-5-ZZ + OH
# Row 329/5990
# Reaction: C7H14-3-Z + O = C7H133-5-ZE + OH
# Row 330/5990
# Reaction: C7H14-3-E + O = C7H133-5-ZE + OH
# Row 331/5990
# Reaction: C7H14-3-E + O = C7H133-5-EE + OH
# Row 332/5990
# Reaction: NC5H11CHO + OH = NC5H11CO + H2O
# Row 333/5990
# Reaction: C5H5CH3-2 + O = C5H5CH2-2 + OH
# Row 334/5990
# Reaction: NEC6-4 + H = NEC6
# Row 335/5990
# Reaction: C6H8-Z + O2 = C6H7-2-ZZ + HO2
# Row 336/5990
# Reaction: C6H8-E + O2 = C6H7-2-ZE + HO2
# Row 337/5990
# Reaction: C6H8-Z + O2 = C6H7-2-EZ + HO2
# Row 338/5990
# Reaction: C6H8-E + O2 = C6H7-2-EE + HO2
# Row 339/5990
# Reaction: C6H10D24-ZZ + H = C6H112-4-ZZ
# Row 340/5990
# Reaction: C6H10D24-ZZ + H = C6H112-4-ZE
# Row 341/5990
# Reaction: C6H10D24-ZE + H = C6H112-4-EZ
# Row 342/5990
# Reaction: C6H10D24-ZE + H = C6H112-4-EE
# Row 343/5990
# Reaction: C6H10D24-ZE + H = C6H112-4-ZZ
# Row 344/5990
# Reaction: C6H10D24-ZE + H = C6H112-4-ZE
# Row 345/5990
# Reaction: C6H10D24-EE + H = C6H112-4-EZ
# Row 346/5990
# Reaction: C6H10D24-EE + H = C6H112-4-EE
# Row 347/5990
# Reaction: C7H121KET53-A0 = C7H121KET53O-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H121KET53-Ar = C7H121KET53O-Ar + OH
#  - Missing enantiomer: C7H121KET53-A1 = C7H121KET53O-A1 + OH
# Row 348/5990
# Reaction: C7H14-2-Z + O = C7H132-4-ZZ + OH
# Row 349/5990
# Reaction: C7H14-2-Z + O = C7H132-4-ZE + OH
# Row 350/5990
# Reaction: C7H14-2-E + O = C7H132-4-EZ + OH
# Row 351/5990
# Reaction: C7H14-2-E + O = C7H132-4-EE + OH
# Row 352/5990
# Reaction: C7H131-4O2-A0 = C7H121OOH4-3-ZA0
#  - Reaction is chiral.
#  - Racemic name: C7H131-4O2-Ar = C7H121OOH4-3-ZAr
#  - Missing enantiomer: C7H131-4O2-A1 = C7H121OOH4-3-ZA1
# Row 353/5990
# Reaction: C7H131-4O2-A0 = C7H121OOH4-3-EA0
#  - Reaction is chiral.
#  - Racemic name: C7H131-4O2-Ar = C7H121OOH4-3-EAr
#  - Missing enantiomer: C7H131-4O2-A1 = C7H121OOH4-3-EA1
# Row 354/5990
# Reaction: C7H131-4O2-A1 = C7H121OOH4-3-ZA1
#  - Reaction is chiral.
#  - Racemic name: C7H131-4O2-Ar = C7H121OOH4-3-ZAr
#  - Missing enantiomer: C7H131-4O2-A0 = C7H121OOH4-3-ZA0
# Row 355/5990
# Reaction: C7H131-4O2-A1 = C7H121OOH4-3-EA1
#  - Reaction is chiral.
#  - Racemic name: C7H131-4O2-Ar = C7H121OOH4-3-EAr
#  - Missing enantiomer: C7H131-4O2-A0 = C7H121OOH4-3-EA0
# Row 356/5990
# Reaction: C6H5CH2OH + OH = C6H5CHOH + H2O
# Row 357/5990
# Reaction: C7H15-3(+M) = NC3H7 + C4H8-1(+M)
# Row 358/5990
# Reaction: C6H11Q24-1-AA0 = C6H11O12-4OOH-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q24-1-AAr = C6H11O12-4OOH-ABr + OH
# ...
#  - Missing enantiomer: XC6OOH2-1-A1 = XC6D1 + HO2
# Row 5868/5990
# Reaction: IC6OOH4-1-AA0 + O2 = IC6OOH4-1O2-AA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-1-AAr + O2 = IC6OOH4-1O2-AAr
#  - Missing enantiomer: IC6OOH4-1-AA1 + O2 = IC6OOH4-1O2-AA1
# Row 5869/5990
# Reaction: IC6OOH4-1-AB0 + O2 = IC6OOH4-1O2-AB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-1-ABr + O2 = IC6OOH4-1O2-ABr
#  - Missing enantiomer: IC6OOH4-1-AB1 + O2 = IC6OOH4-1O2-AB1
# Row 5870/5990
# Reaction: C6H101OOH4-3-ZA0 = ETES1-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH4-3-ZAr = ETES1-ABr + OH
#  - Missing enantiomer: C6H101OOH4-3-ZA1 = ETES1-AB1 + OH
# Row 5871/5990
# Reaction: C6H101OOH4-3-EA0 = ETES1-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH4-3-EAr = ETES1-ABr + OH
#  - Missing enantiomer: C6H101OOH4-3-EA1 = ETES1-AB1 + OH
# Row 5872/5990
# Reaction: C6H101OOH4-3-ZA1 = ETES1-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH4-3-ZAr = ETES1-AAr + OH
#  - Missing enantiomer: C6H101OOH4-3-ZA0 = ETES1-AA1 + OH
# Row 5873/5990
# Reaction: C6H101OOH4-3-EA1 = ETES1-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH4-3-EAr = ETES1-AAr + OH
#  - Missing enantiomer: C6H101OOH4-3-EA0 = ETES1-AA1 + OH
# Row 5874/5990
# Reaction: XC6D2 + CH3 = XC6D1-3 + CH4
# Row 5875/5990
# Reaction: C7H14-3-Z + O = C7H133-6-Z + OH
# Row 5876/5990
# Reaction: C7H14-3-E + O = C7H133-6-E + OH
# Row 5877/5990
# Reaction: C7H121OOH6-5-A0 = C7H121-5-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH6-5-Ar = C7H121-5-Z + HO2
#  - Missing enantiomer: C7H121OOH6-5-A1 = C7H121-5-Z + HO2
# Row 5878/5990
# Reaction: C7H121OOH6-5-A0 = C7H121-5-E + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H121OOH6-5-Ar = C7H121-5-E + HO2
#  - Missing enantiomer: C7H121OOH6-5-A1 = C7H121-5-E + HO2
# Row 5879/5990
# Reaction: IC6D4 = C3H5-A + IC3H7
# Row 5880/5990
# Reaction: XC6 + CH3O2 = XC6-2 + CH3O2H
# Row 5881/5990
# Reaction: C7H14OOH3-2O-AB0 = C6KET12-A1 + CH3
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-2O-ABr = C6KET12-Ar + CH3
#  - Missing enantiomer: C7H14OOH3-2O-AB1 = C6KET12-A0 + CH3
# Row 5882/5990
# Reaction: C7H14OOH3-2O-AA0 = C6KET12-A0 + CH3
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-2O-AAr = C6KET12-Ar + CH3
#  - Missing enantiomer: C7H14OOH3-2O-AA1 = C6KET12-A1 + CH3
# Row 5883/5990
# Reaction: NC7H16 + H = C7H15-1 + H2
# Row 5884/5990
# Reaction: IC6D1 + CH3O2 = IC6D1-1A + CH3O2H
# Row 5885/5990
# Reaction: I3C6D3-2-Z + HO2 = I3C6D3-2OOH-A0
#  - Reaction is chiral.
#  - Racemic name: I3C6D3-2-Z + HO2 = I3C6D3-2OOH-Ar
#  - Missing enantiomer: I3C6D3-2-Z + HO2 = I3C6D3-2OOH-A1
# Row 5886/5990
# Reaction: I3C6D3-2-E + HO2 = I3C6D3-2OOH-A0
#  - Reaction is chiral.
#  - Racemic name: I3C6D3-2-E + HO2 = I3C6D3-2OOH-Ar
#  - Missing enantiomer: I3C6D3-2-E + HO2 = I3C6D3-2OOH-A1
# Row 5887/5990
# Reaction: C6H12-1 + O = C6H111-1-E + OH
# Row 5888/5990
# Reaction: C6H12-1 + O = C6H111-1-Z + OH
# Row 5889/5990
# Reaction: IC5T1 + CH3 = IC5T1-3 + CH4
# Row 5890/5990
# Reaction: C6H12OOH2-4O2-AA0 = C6H11-2D5OOH-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH2-4O2-AAr = C6H11-2D5OOH-ZAr + HO2
#  - Missing enantiomer: C6H12OOH2-4O2-AA1 = C6H11-2D5OOH-ZA1 + HO2
# Row 5891/5990
# Reaction: C6H12OOH2-4O2-AB0 = C6H11-2D5OOH-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH2-4O2-ABr = C6H11-2D5OOH-EAr + HO2
#  - Missing enantiomer: C6H12OOH2-4O2-AB1 = C6H11-2D5OOH-EA1 + HO2
# Row 5892/5990
# Reaction: C6H12OOH2-4O2-AB1 = C6H11-2D5OOH-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH2-4O2-ABr = C6H11-2D5OOH-ZAr + HO2
#  - Missing enantiomer: C6H12OOH2-4O2-AB0 = C6H11-2D5OOH-ZA0 + HO2
# Row 5893/5990
# Reaction: C6H12OOH2-4O2-AA1 = C6H11-2D5OOH-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH2-4O2-AAr = C6H11-2D5OOH-EAr + HO2
#  - Missing enantiomer: C6H12OOH2-4O2-AA0 = C6H11-2D5OOH-EA0 + HO2
# Row 5894/5990
# Reaction: C6KET15O-A1 = CH3CHO + C3H6CHO-3
#  - Reaction is chiral.
#  - Racemic name: C6KET15O-Ar = CH3CHO + C3H6CHO-3
#  - Missing enantiomer: C6KET15O-A0 = CH3CHO + C3H6CHO-3
# Row 5895/5990
# Reaction: C6H12-1 + CH3O = C6H111-4 + CH3OH
# Row 5896/5990
# Reaction: C5H5CH3-1 + O = C5H4CH3 + OH
# Row 5897/5990
# Reaction: I3C6D1-A0 + O2 = I3C6D1-6-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-Ar + O2 = I3C6D1-6-Ar + HO2
#  - Missing enantiomer: I3C6D1-A1 + O2 = I3C6D1-6-A1 + HO2
# Row 5898/5990
# Reaction: I3C6Q14-2-A1 = I3C6D1-4OOH-A0 + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6Q14-2-Ar = I3C6D1-4OOH-Ar + HO2
#  - Missing enantiomer: I3C6Q14-2-A0 = I3C6D1-4OOH-A1 + HO2
# Row 5899/5990
# Reaction: IC6D3-Z + O2CHO = IC6D3-1-ZA0 + HO2CHO
#  - Reaction is chiral.
#  - Racemic name: IC6D3-Z + O2CHO = IC6D3-1-ZAr + HO2CHO
#  - Missing enantiomer: IC6D3-Z + O2CHO = IC6D3-1-ZA1 + HO2CHO
# Row 5900/5990
# Reaction: IC6D3-E + O2CHO = IC6D3-1-EA0 + HO2CHO
#  - Reaction is chiral.
#  - Racemic name: IC6D3-E + O2CHO = IC6D3-1-EAr + HO2CHO
#  - Missing enantiomer: IC6D3-E + O2CHO = IC6D3-1-EA1 + HO2CHO
# Row 5901/5990
# Reaction: C7H14-2-Z + H = C7H15-3
# Row 5902/5990
# Reaction: C7H14-2-E + H = C7H15-3
# Row 5903/5990
# Reaction: IC6D14 + OH = IC6D13-5R-ZZ + H2O
# Row 5904/5990
# Reaction: IC6D14 + OH = IC6D13-5R-ZE + H2O
# Row 5905/5990
# Reaction: IC6D14 + OH = IC6D13-5R-EZ + H2O
# Row 5906/5990
# Reaction: IC6D14 + OH = IC6D13-5R-EE + H2O
# Row 5907/5990
# Reaction: C6H11-2D5O-ZA1 = CH3CHO + C4H71-3-Z
#  - Reaction is chiral.
#  - Racemic name: C6H11-2D5O-ZAr = CH3CHO + C4H71-3-Z
#  - Missing enantiomer: C6H11-2D5O-ZA0 = CH3CHO + C4H71-3-Z
# Row 5908/5990
# Reaction: C6H11-2D5O-EA1 = CH3CHO + C4H71-3-E
#  - Reaction is chiral.
#  - Racemic name: C6H11-2D5O-EAr = CH3CHO + C4H71-3-E
#  - Missing enantiomer: C6H11-2D5O-EA0 = CH3CHO + C4H71-3-E
# Row 5909/5990
# Reaction: PC4H9CHO + CH3O2 = PC4H8CHO-4 + CH3O2H
# Row 5910/5990
# Reaction: C6H12-1 + OH = C6H111-4 + H2O
# Row 5911/5990
# Reaction: AC5H10 + CH3O2 = AC5H9-D + CH3O2H
# Row 5912/5990
# Reaction: C7H14OOH1-5O-A0 = NC5KET15 + C2H5
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH1-5O-Ar = NC5KET15 + C2H5
#  - Missing enantiomer: C7H14OOH1-5O-A1 = NC5KET15 + C2H5
# Row 5913/5990
# Reaction: XC6 + O = XC6-2 + OH
# Row 5914/5990
# Reaction: IC6-2 + O2 = IC6D1 + HO2
# Row 5915/5990
# Reaction: XC6Q23-1-A0 = XC6D1-3OOH + HO2
#  - Reaction is chiral.
#  - Racemic name: XC6Q23-1-Ar = XC6D1-3OOH + HO2
#  - Missing enantiomer: XC6Q23-1-A1 = XC6D1-3OOH + HO2
# Row 5916/5990
# Reaction: NC6D1KET63O-A1 = C2H3CHO + CH2CH2CHO
#  - Reaction is chiral.
#  - Racemic name: NC6D1KET63O-Ar = C2H3CHO + CH2CH2CHO
#  - Missing enantiomer: NC6D1KET63O-A0 = C2H3CHO + CH2CH2CHO
# Row 5917/5990
# Reaction: I3C6D2-6O-E = AC5H9-C-Z + CH2O
# Row 5918/5990
# Reaction: I3C6D2-6O-Z = AC5H9-C-E + CH2O
# Row 5919/5990
# Reaction: C5H5CH3-2 + O2 = C5H4CH3 + HO2
# Row 5920/5990
# Reaction: C7H15-1 = C7H15-4
# Row 5921/5990
# Reaction: C3H6 + IC3H7O2 = C3H5-A + IC3H7O2H
# Row 5922/5990
# Reaction: IC6OOH3-2O2-A0 = IC6Q23-1-AA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-2O2-Ar = IC6Q23-1-AAr
#  - Missing enantiomer: IC6OOH3-2O2-A1 = IC6Q23-1-AA1
# Row 5923/5990
# Reaction: IC6OOH3-2O2-A0 = IC6Q23-1-AB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH3-2O2-Ar = IC6Q23-1-ABr
#  - Missing enantiomer: IC6OOH3-2O2-A1 = IC6Q23-1-AB1
# Row 5924/5990
# Reaction: C6H101-5 + HO2 = C6H9-A-Z + H2O2
# Row 5925/5990
# Reaction: C6H101-5 + HO2 = C6H9-A-E + H2O2
# Row 5926/5990
# Reaction: I3C6D2-Z + CH3O2 = I3C6D2-5-ZZ + CH3O2H
# Row 5927/5990
# Reaction: I3C6D2-Z + CH3O2 = I3C6D2-5-ZE + CH3O2H
# Row 5928/5990
# Reaction: I3C6D2-E + CH3O2 = I3C6D2-5-ZE + CH3O2H
# Row 5929/5990
# Reaction: I3C6D2-E + CH3O2 = I3C6D2-5-EE + CH3O2H
# Row 5930/5990
# Reaction: C7H14OH-1O2-2-A0 = C7H13OH1Q2-6-A0
#  - Reaction is chiral.
#  - Racemic name: C7H14OH-1O2-2-Ar = C7H13OH1Q2-6-Ar
#  - Missing enantiomer: C7H14OH-1O2-2-A1 = C7H13OH1Q2-6-A1
# Row 5931/5990
# Reaction: C7H14OH-1O2-2-A1 = C7H13OH1Q2-6-A1
#  - Reaction is chiral.
#  - Racemic name: C7H14OH-1O2-2-Ar = C7H13OH1Q2-6-Ar
#  - Missing enantiomer: C7H14OH-1O2-2-A0 = C7H13OH1Q2-6-A0
# Row 5932/5990
# Reaction: C6H11Q23-1-AA0 = C6H11O13-2OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q23-1-AAr = C6H11O13-2OOH-AAr + OH
#  - Missing enantiomer: C6H11Q23-1-AA1 = C6H11O13-2OOH-AA1 + OH
# Row 5933/5990
# Reaction: C6H11Q23-1-AB0 = C6H11O13-2OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H11Q23-1-ABr = C6H11O13-2OOH-ABr + OH
#  - Missing enantiomer: C6H11Q23-1-AB1 = C6H11O13-2OOH-AB0 + OH
# Row 5934/5990
# Reaction: NEC6OOH1-4 = NEC6O1-4 + OH
# Row 5935/5990
# Reaction: C6H12OOH1-4O2-A0 = C6H11Q14-5-A0
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH1-4O2-Ar = C6H11Q14-5-Ar
#  - Missing enantiomer: C6H12OOH1-4O2-A1 = C6H11Q14-5-A1
# Row 5936/5990
# Reaction: C6H12OOH1-4O2-A1 = C6H11Q14-5-A1
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH1-4O2-Ar = C6H11Q14-5-Ar
#  - Missing enantiomer: C6H12OOH1-4O2-A0 = C6H11Q14-5-A0
# Row 5937/5990
# Reaction: C6H5O + H(+M) = C6H5OH(+M)
# Row 5938/5990
# Reaction: XC6D1-3 + HO2 = XC6D1-3OOH
# Row 5939/5990
# Reaction: C6H12-2-Z + CH3O = C6H112-6-Z + CH3OH
# Row 5940/5990
# Reaction: C6H12-2-E + CH3O = C6H112-6-E + CH3OH
# Row 5941/5990
# Reaction: C7H14OOH4-3O2-AB0 = C7H13-2D4OOH-ZA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH4-3O2-ABr = C7H13-2D4OOH-ZAr + HO2
#  - Missing enantiomer: C7H14OOH4-3O2-AB1 = C7H13-2D4OOH-ZA1 + HO2
# Row 5942/5990
# Reaction: C7H14OOH4-3O2-AA0 = C7H13-2D4OOH-ZA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH4-3O2-AAr = C7H13-2D4OOH-ZAr + HO2
#  - Missing enantiomer: C7H14OOH4-3O2-AA1 = C7H13-2D4OOH-ZA0 + HO2
# Row 5943/5990
# Reaction: C7H14OOH4-3O2-AA1 = C7H13-2D4OOH-EA0 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH4-3O2-AAr = C7H13-2D4OOH-EAr + HO2
#  - Missing enantiomer: C7H14OOH4-3O2-AA0 = C7H13-2D4OOH-EA1 + HO2
# Row 5944/5990
# Reaction: C7H14OOH4-3O2-AB1 = C7H13-2D4OOH-EA1 + HO2
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH4-3O2-ABr = C7H13-2D4OOH-EAr + HO2
#  - Missing enantiomer: C7H14OOH4-3O2-AB0 = C7H13-2D4OOH-EA0 + HO2
# Row 5945/5990
# Reaction: NC6H14 + H = C6H13-2 + H2
# Row 5946/5990
# Reaction: NEC6D3-1 = C2H3 + IC4H8
# Row 5947/5990
# Reaction: C6H12OOH2-5O2-AA0 = C6KET25-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH2-5O2-AAr = C6KET25-Ar + OH
#  - Missing enantiomer: C6H12OOH2-5O2-AA1 = C6KET25-A1 + OH
# Row 5948/5990
# Reaction: C6H12OOH2-5O2-AB1 = C6KET25-A1 + OH
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH2-5O2-ABr = C6KET25-Ar + OH
#  - Missing enantiomer: C6H12OOH2-5O2-AB0 = C6KET25-A0 + OH
# Row 5949/5990
# Reaction: XC6OOH1-4-AA0 = XC6O1-4-AB + OH
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4-AAr = XC6O1-4-AB + OH
#  - Missing enantiomer: XC6OOH1-4-AA1 = XC6O1-4-AB + OH
# Row 5950/5990
# Reaction: XC6OOH1-4-AB0 = XC6O1-4-AA1 + OH
#  - Reaction is chiral.
#  - Racemic name: XC6OOH1-4-ABr = XC6O1-4-AAr + OH
#  - Missing enantiomer: XC6OOH1-4-AB1 = XC6O1-4-AA0 + OH
# Row 5951/5990
# Reaction: I3C6D1-5-A0 + O2 = I3C6D25-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-5-Ar + O2 = I3C6D25-Z + HO2
#  - Missing enantiomer: I3C6D1-5-A1 + O2 = I3C6D25-Z + HO2
# Row 5952/5990
# Reaction: I3C6D1-5-A0 + O2 = I3C6D25-E + HO2
#  - Reaction is chiral.
#  - Racemic name: I3C6D1-5-Ar + O2 = I3C6D25-E + HO2
#  - Missing enantiomer: I3C6D1-5-A1 + O2 = I3C6D25-E + HO2
# Row 5953/5990
# Reaction: I3C6D2-Z + CH3 = I3C6D3-2-Z + CH4
# Row 5954/5990
# Reaction: I3C6D2-E + CH3 = I3C6D3-2-E + CH4
# Row 5955/5990
# Reaction: XC6D1 + CH3O = XC6D1-1A + CH3OH
# Row 5956/5990
# Reaction: IC6Q24-1-AA0 = IC6O14-2OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q24-1-AAr = IC6O14-2OOH-AAr + OH
#  - Missing enantiomer: IC6Q24-1-AA1 = IC6O14-2OOH-AA1 + OH
# Row 5957/5990
# Reaction: IC6Q24-1-AB0 = IC6O14-2OOH-AB0 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6Q24-1-ABr = IC6O14-2OOH-ABr + OH
#  - Missing enantiomer: IC6Q24-1-AB1 = IC6O14-2OOH-AB1 + OH
# Row 5958/5990
# Reaction: C6H5CHO + OH = C6H5CO + H2O
# Row 5959/5990
# Reaction: C6H101OOH3-4-A0 = C6H10D13-Z + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH3-4-Ar = C6H10D13-Z + HO2
#  - Missing enantiomer: C6H101OOH3-4-A1 = C6H10D13-Z + HO2
# Row 5960/5990
# Reaction: C6H101OOH3-4-A0 = C6H10D13-E + HO2
#  - Reaction is chiral.
#  - Racemic name: C6H101OOH3-4-Ar = C6H10D13-E + HO2
#  - Missing enantiomer: C6H101OOH3-4-A1 = C6H10D13-E + HO2
# Row 5961/5990
# Reaction: IC6D4-2 + O2 = IC6D24 + HO2
# Row 5962/5990
# Reaction: C6H12OOH3-4O-AB0 = NC4KET12-A1 + C2H5
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-4O-ABr = NC4KET12-Ar + C2H5
#  - Missing enantiomer: C6H12OOH3-4O-AB1 = NC4KET12-A0 + C2H5
# Row 5963/5990
# Reaction: C6H12OOH3-4O-AA0 = NC4KET12-A0 + C2H5
#  - Reaction is chiral.
#  - Racemic name: C6H12OOH3-4O-AAr = NC4KET12-Ar + C2H5
#  - Missing enantiomer: C6H12OOH3-4O-AA1 = NC4KET12-A1 + C2H5
# Row 5964/5990
# Reaction: C3H8 + IC3H7O2 = NC3H7 + IC3H7O2H
# Row 5965/5990
# Reaction: C7H14OOH3-7-A0 + O2 = C7H14OOH3-7O2-A0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-7-Ar + O2 = C7H14OOH3-7O2-Ar
#  - Missing enantiomer: C7H14OOH3-7-A1 + O2 = C7H14OOH3-7O2-A1
# Row 5966/5990
# Reaction: IC6 + CH3 = IC6-3 + CH4
# Row 5967/5990
# Reaction: NEC6D3 = CC5H9-B + CH3
# Row 5968/5990
# Reaction: IC6KET1-2O-A0 = NC3H7COCH3 + HCO
#  - Reaction is chiral.
#  - Racemic name: IC6KET1-2O-Ar = NC3H7COCH3 + HCO
#  - Missing enantiomer: IC6KET1-2O-A1 = NC3H7COCH3 + HCO
# Row 5969/5990
# Reaction: C7H14OOH3-6-A0 + O2 = C7H14OOH3-6O2-AA0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-6-Ar + O2 = C7H14OOH3-6O2-AAr
#  - Missing enantiomer: C7H14OOH3-6-A1 + O2 = C7H14OOH3-6O2-AA1
# Row 5970/5990
# Reaction: C7H14OOH3-6-A1 + O2 = C7H14OOH3-6O2-AB0
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-6-Ar + O2 = C7H14OOH3-6O2-ABr
#  - Missing enantiomer: C7H14OOH3-6-A0 + O2 = C7H14OOH3-6O2-AB1
# Row 5971/5990
# Reaction: NEC6Q13-1A-AA0 = NEC6O11A-3OOH-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: NEC6Q13-1A-AAr = NEC6O11A-3OOH-Ar + OH
#  - Missing enantiomer: NEC6Q13-1A-AA1 = NEC6O11A-3OOH-A1 + OH
# Row 5972/5990
# Reaction: NEC6Q13-1A-AB0 = NEC6O11A-3OOH-A0 + OH
#  - Reaction is chiral.
#  - Racemic name: NEC6Q13-1A-ABr = NEC6O11A-3OOH-Ar + OH
#  - Missing enantiomer: NEC6Q13-1A-AB1 = NEC6O11A-3OOH-A1 + OH
# Row 5973/5990
# Reaction: IC6D2 + HO2 = IC6D1-3-Z + H2O2
# Row 5974/5990
# Reaction: IC6D2 + HO2 = IC6D1-3-E + H2O2
# Row 5975/5990
# Reaction: C6H10D14-Z + H = C6H112-6-Z
# Row 5976/5990
# Reaction: C6H10D14-E + H = C6H112-6-E
# Row 5977/5990
# Reaction: IC6OOH4-5-A0 = IC6O4-5-A1 + OH
#  - Reaction is chiral.
#  - Racemic name: IC6OOH4-5-Ar = IC6O4-5-Ar + OH
#  - Missing enantiomer: IC6OOH4-5-A1 = IC6O4-5-A0 + OH
# Row 5978/5990
# Reaction: I3C6Q15-6-AA0 = I3C6O12-6OOH-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q15-6-AAr = I3C6O12-6OOH-AAr + OH
#  - Missing enantiomer: I3C6Q15-6-AA1 = I3C6O12-6OOH-AA1 + OH
# Row 5979/5990
# Reaction: I3C6Q15-6-AB1 = I3C6O12-6OOH-AB1 + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q15-6-ABr = I3C6O12-6OOH-ABr + OH
#  - Missing enantiomer: I3C6Q15-6-AB0 = I3C6O12-6OOH-AB0 + OH
# Row 5980/5990
# Reaction: C7H14OOH3-5-A0 = C7H14O3-5-AA0 + OH
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-5-Ar = C7H14O3-5-AAr + OH
#  - Missing enantiomer: C7H14OOH3-5-A1 = C7H14O3-5-AA1 + OH
# Row 5981/5990
# Reaction: C7H14OOH3-5-A1 = C7H14O3-5-AB + OH
#  - Reaction is chiral.
#  - Racemic name: C7H14OOH3-5-Ar = C7H14O3-5-AB + OH
#  - Missing enantiomer: C7H14OOH3-5-A0 = C7H14O3-5-AB + OH
# Row 5982/5990
# Reaction: IC6OOH1-3O2-AA0 = IC6Q13-4-AA0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-3O2-AAr = IC6Q13-4-AAr
#  - Missing enantiomer: IC6OOH1-3O2-AA1 = IC6Q13-4-AA1
# Row 5983/5990
# Reaction: IC6OOH1-3O2-AB0 = IC6Q13-4-AB0
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-3O2-ABr = IC6Q13-4-ABr
#  - Missing enantiomer: IC6OOH1-3O2-AB1 = IC6Q13-4-AB1
# Row 5984/5990
# Reaction: IC6OOH1-3O2-AB1 = IC6Q13-4-AB1
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-3O2-ABr = IC6Q13-4-ABr
#  - Missing enantiomer: IC6OOH1-3O2-AB0 = IC6Q13-4-AB0
# Row 5985/5990
# Reaction: IC6OOH1-3O2-AA1 = IC6Q13-4-AA1
#  - Reaction is chiral.
#  - Racemic name: IC6OOH1-3O2-AAr = IC6Q13-4-AAr
#  - Missing enantiomer: IC6OOH1-3O2-AA0 = IC6Q13-4-AA0
# Row 5986/5990
# Reaction: C6H112O2-6-Z = C6H102OOH6-5-Z
# Row 5987/5990
# Reaction: C6H112O2-6-E = C6H102OOH6-5-E
# Row 5988/5990
# Reaction: I3C6Q14-6-A0 = I3C6O16-4OOH + OH
#  - Reaction is chiral.
#  - Racemic name: I3C6Q14-6-Ar = I3C6O16-4OOH + OH
#  - Missing enantiomer: I3C6Q14-6-A1 = I3C6O16-4OOH + OH
# Row 5989/5990
# Reaction: H + FULVENE = C5H5CH2-2

# %%
print('Retrieving full NUIG-Pyro reaction expansion from non-redundant list')
FUEX_PYR_RXN_DF = add_missing_reaction_enantiomers(
    NREX_PYR_RXN_DF, FUEX_PYR_SPC_DF)

# %%
# 4. construct a complete, non-redundant model by lumping enantiomers
def lump_enantiomers(rxn_df, spc_df):
    """ Lump species and reactions, assuming a racemic mixture
    """
    # First, lump species. This list is equivalent to the non-redundant species list,
    # with names replaced by racemic names
    lu_spc_df = spc_df.groupby('racem-name', sort=False).apply(lambda g: g.iloc[0])
    lu_spc_df.rename({'name': 'stereo-name'}, axis=1, inplace=True)
    lu_spc_df.index.name = 'name'
    lu_spc_df.pop('racem-name')
    lu_spc_df.reset_index(inplace=True)

    # Second, lump reactions. This is *not* equivalent to the non-redundant reaction list
    # (a.) Convert serialized parameter strings into objects
    rxn_df = helpers.reactions_with_params_objects(rxn_df)

    # (b.) Lump products, adding rate constants
    def _lump_reactions(grp_df):
        row = grp_df.iloc[0]
        row['stereo-name'] = grp_df.index[0]
        objs = grp_df['params']
        nreac = row['num-reac-enants']
        row['params'] = sum(objs) / (2 ** nreac)  # __radd__ is overloaded
        return row

    lu_rxn_df = rxn_df.groupby('racem-name', sort=False).apply(_lump_reactions)
    lu_rxn_df.index.name = 'name'
    lu_rxn_df.pop('racem-name')
    lu_rxn_df.insert(0, 'stereo-name', lu_rxn_df.pop('stereo-name'))
    lu_rxn_df.reset_index(inplace=True)
    return lu_rxn_df, lu_spc_df


LUMP_C67_RXN_DF, LUMP_C67_SPC_DF = lump_enantiomers(FUEX_C67_RXN_DF, FUEX_C67_SPC_DF)
LUMP_PYR_RXN_DF, LUMP_PYR_SPC_DF = lump_enantiomers(FUEX_PYR_RXN_DF, FUEX_PYR_SPC_DF)

LUMP_C67_RXN_PATH = 'reactions/06_reactions-lumped_nuig-c6-7.csv'
LUMP_C67_RXN_DF.to_csv(LUMP_C67_RXN_PATH, quotechar="'")
LUMP_PYR_RXN_PATH = 'reactions/06_reactions-lumped_nuig-pyro.csv'
LUMP_PYR_RXN_DF.to_csv(LUMP_PYR_RXN_PATH, quotechar="'")

# %%
# 5. generate reaction parameters dictionaries
LUMP_C67_RXN_DCT = helpers.mechanism_dict(LUMP_C67_RXN_DF)
LUMP_PYR_RXN_DCT = helpers.mechanism_dict(LUMP_PYR_RXN_DF)

# %%
# 6. restrict the species dataframes based on the reaction lists
LUMP_C67_SPC_DF = helpers.species_for_mechanism(LUMP_C67_SPC_DF, LUMP_C67_RXN_DCT)
LUMP_PYR_SPC_DF = helpers.species_for_mechanism(LUMP_PYR_SPC_DF, LUMP_PYR_RXN_DCT)

# %%
# 7. write the original and fully expanded submechanisms
LUMP_C67_SPC_PATH = 'mechanisms/06_nr-exp_nuig-c6-7.csv'
LUMP_C67_RXN_PATH = 'mechanisms/06_nr-exp_nuig-c6-7.txt'
LUMP_PYR_SPC_PATH = 'mechanisms/06_nr-exp_nuig-pyro.csv'
LUMP_PYR_RXN_PATH = 'mechanisms/06_nr-exp_nuig-pyro.txt'

# a. write the species files
LUMP_C67_SPC_DF.to_csv(LUMP_C67_SPC_PATH, quotechar="'", index=False)
LUMP_PYR_SPC_DF.to_csv(LUMP_PYR_SPC_PATH, quotechar="'", index=False)

# b. write the reaction/mechanism files
LUMP_C67_MECH_STR = helpers.mechanism_string(LUMP_C67_RXN_DCT, LUMP_C67_SPC_DF)
LUMP_PYR_MECH_STR = helpers.mechanism_string(LUMP_PYR_RXN_DCT, LUMP_PYR_SPC_DF)

ioformat.pathtools.write_file(LUMP_C67_MECH_STR, '.', LUMP_C67_RXN_PATH)
ioformat.pathtools.write_file(LUMP_PYR_MECH_STR, '.', LUMP_PYR_RXN_PATH)
